# %%
from src.data.dataloader import *
from src.data.csv_generator import save_to_csv


import pandas as pd


df_image = get_image_data()
df_caption = get_caption_dataset(df_image)

save_to_csv(df_image, 'data/newyorker_caption_contest/df_complete.csv')

# %%
df_image.to_csv("data/newyorker_caption_contest/df_complete.csv", index=False)

# %%
df_caption
# Out:
#          contest_id       date  rank  \
# 0               510 2016-03-07     0
# 1               510 2016-03-07     1
# 2               510 2016-03-07     2
# 3               510 2016-03-07     3
# 4               510 2016-03-07     4
# ...             ...        ...   ...
# 2263043         895 2023-09-18  4953
# 2263044         895 2023-09-18  4954
# 2263045         895 2023-09-18  4955
# 2263046         895 2023-09-18  4956
# 2263047         895 2023-09-18  4957
#
#                                                    caption      mean  \
# 0                I'm a congressman--obstruction is my job.  1.913043
# 1        I'm what they mean when they say, 'The middle ...  1.842105
# 2                        Does this suit make me look flat?  1.711111
# 3          When the right woman comes along, I'll know it.  1.625000
# 4        I used to lie in the gutter, but then I quit d...  1.617647
# ...                                                    ...       ...
# 2263043  Looks like we took a wrong turn at the Hubble ...  1.023256
# 2263044             Post-modern just doesn't do it for me.  1.022222
# 2263045  How was I supposed to know they covered themse...  1.020833
# 2263046  No, they wanted us to teleport the giveaway ca...  1.020619
# 2263047  The cinema is still here, but they aren’t play...  1.012195
#
#          precision  votes  not_funny  somewhat_funny  funny
# 0         0.094022     69         24              27     18
# 1         0.191381     19          8               6      5
# 2         0.112915     45         21              16      8
# 3         0.116657     32         15              14      3
# 4         0.133610     34         19               9      6
# ...            ...    ...        ...             ...    ...
# 2263043   0.016347     86         84               2      0
# 2263044   0.015625     90         88               2      0
# 2263045   0.014654     96         94               2      0
# 2263046   0.020619     97         96               0      1
# 2263047   0.012270     82         81               1      0
#
# [2263048 rows x 10 columns]

# %%
df_image
# Out:
#      contest_id  num_captions                          image_locations  \
# 0           510        3905.0                             [the street]
# 1           511        3325.0  [the front hard, a residential walkway]
# 2           512        4399.0              [yoga place, a yoga studio]
# 3           513        4141.0               [a workplace, an elevator]
# 4           514        3951.0                                 [plains]
# ..          ...           ...                                      ...
# 379         891           NaN                                      NaN
# 380         892           NaN                                      NaN
# 381         893           NaN                                      NaN
# 382         894           NaN                                      NaN
# 383         895           NaN                                      NaN
#
#                                     image_descriptions  \
# 0    [A man is relaxing on a city street. Others ar...
# 1    [A man in a winter coat and cap is looking at ...
# 2    [A man and woman are standing facing one anoth...
# 3    [Three business men are walking down a hall. T...
# 4    [Some cowboys are riding through the desert. T...
# ..                                                 ...
# 379                                                NaN
# 380                                                NaN
# 381                                                NaN
# 382                                                NaN
# 383                                                NaN
#
#                             image_uncanny_descriptions  \
# 0    [A man is just laying in the middle of the sid...
# 1    [It's unusual to see someone holding a snow sh...
# 2    [Nothing is really out of place in this image....
# 3    [A suit case is usually carried by one person ...
# 4    [There are rocking horses in place of real hor...
# ..                                                 ...
# 379                                                NaN
# 380                                                NaN
# 381                                                NaN
# 382                                                NaN
# 383                                                NaN
#
#                                               entities  \
# 0    [https://en.wikipedia.org/wiki/Bystander_effec...
# 1    [https://en.wikipedia.org/wiki/Snowball_fight,...
# 2    [https://en.wikipedia.org/wiki/Rug, https://en...
# 3    [https://en.wikipedia.org/wiki/Worker_cooperat...
# 4    [https://en.wikipedia.org/wiki/Rocking_horse, ...
# ..                                                 ...
# 379                                                NaN
# 380                                                NaN
# 381                                                NaN
# 382                                                NaN
# 383                                                NaN
#
#                                              questions  \
# 0                            [Why is he laying there?]
# 1    [Is the man overly small or the shovel overly ...
# 2    [Why is the man carrying a huge rug?, Why is t...
# 3    [Why is the briefcase big enough for three peo...
# 4                    [Why is this chase taking place?]
# ..                                                 ...
# 379                                                NaN
# 380                                                NaN
# 381                                                NaN
# 382                                                NaN
# 383                                                NaN
#
#                                      Top Rated caption  \
# 0          “I'm a congressman--obstruction is my job.”
# 1                                        “I'm hourly.”
# 2               “We're pretentious, not ostentatious.”
# 3    “I'm just saying, I can see why the 'brief'cas...
# 4                                    “No, you grow up”
# ..                                                 ...
# 379         “Sorry, only the catcher works from home.”
# 380  “Yes, it's called Thesaurus, but you're not re...
# 381           “The seller isn't willing to come down.”
# 382            “See how the nose seems to follow you?”
# 383  “Do you think death rays would be considered e...
#
#     The New Yorker's winner       date  Number of votes
# 0                       NaN 2016-03-07            82627
# 1                       NaN 2016-03-14            56660
# 2                       NaN 2016-03-21            43120
# 3                       NaN 2016-03-27            34013
# 4                       NaN 2016-04-03           192198
# ..                      ...        ...              ...
# 379                     NaN 2023-08-21           928856
# 380                     NaN 2023-08-28           788251
# 381                     NaN 2023-09-04          1085745
# 382                     NaN 2023-09-11           878676
# 383                     NaN 2023-09-18           777820
#
# [384 rows x 11 columns]

# %% [markdown]
# ## Google trends ##
# This section aims to correlate Google search interest with our humor dataset to see whether public attention to certain topics aligns with shifts in humor themes. We use the weekly Google Trends data stored in data/GoogleTrends and compare it with our own time series of humor types to analyze how closely real-world events and humor evolution are connected over time. £

# %%
import sys, os
sys.path.append(os.path.abspath("src"))  
from utils.utils_import import *

# %% [markdown]
# ### Words frequency ###

# %%
# NLTK setup (robust)
import nltk
from nltk.corpus import stopwords
try:
    from nltk.tokenize import word_tokenize
except Exception:
    word_tokenize = None

def _ensure_nltk():
    # Try exact resources required by recent NLTK
    for pkg in ["stopwords", "punkt", "punkt_tab"]:
        try:
            nltk.data.find(f"corpora/{pkg}") if pkg=="stopwords" else nltk.data.find(f"tokenizers/{pkg}")
        except LookupError:
            nltk.download(pkg, quiet=True)

_ensure_nltk()

# After ensuring, import again (in case it failed earlier)
from nltk.corpus import stopwords
try:
    from nltk.tokenize import word_tokenize as _wt
    word_tokenize = _wt
except Exception:
    pass

EN_STOP = set(stopwords.words('english'))

# ---- config ----
PATH = pathlib.Path("data/newyorker_caption_contest/contests.json")
FIELDS = ["image_descriptions", "image_uncanny_descriptions", "image_locations", "questions"]
OUTDIR = pathlib.Path("data/GoogleTrends/frequent_words")

# Fallback regex tokenizer (letters only, >=3 chars)
TOKEN_RE = re.compile(r"[A-Za-z]{3,}")

def load_records(path: pathlib.Path):
    txt = path.read_text(encoding="utf-8")
    try:
        obj = json.loads(txt)
    except json.JSONDecodeError:
        recs = []
        with path.open(encoding="utf-8") as f:
            for line in f:
                line = line.strip()
                if line:
                    recs.append(json.loads(line))
        return recs
    if isinstance(obj, list):
        return obj
    if isinstance(obj, dict):
        if "contests" in obj and isinstance(obj["contests"], list):
            return obj["contests"]
        return [obj]
    raise ValueError("Unsupported JSON structure")

def collect_texts(records, field):
    out = []
    for r in records:
        m = r.get("metadata") or {}
        v = m.get(field) if isinstance(m, dict) else None
        if isinstance(v, list):
            out.extend([s for s in v if isinstance(s, str)])
        elif isinstance(v, str):
            out.append(v)
    return out

def tokenize_lower(text: str):
    """Prefer NLTK word_tokenize; fallback to regex if unavailable."""
    if word_tokenize is not None:
        try:
            return [w.lower() for w in word_tokenize(text)]
        except LookupError:
            # If punkt/punkt_tab still missing for some reason, fallback
            return [w.lower() for w in TOKEN_RE.findall(text)]
    else:
        return [w.lower() for w in TOKEN_RE.findall(text)]

def count_tokens_nltk(texts):
    c = Counter()
    for t in texts:
        tokens = tokenize_lower(t)
        # keep only alphabetic tokens, >=3 chars, not in stopwords
        filtered = [w for w in tokens if w.isalpha() and len(w) >= 3 and w not in EN_STOP]
        c.update(filtered)
    return c

def save_counts_csv(counter: Counter, out_path: pathlib.Path):
    out_path.parent.mkdir(parents=True, exist_ok=True)
    with out_path.open("w", newline="", encoding="utf-8") as f:
        w = csv.writer(f)
        w.writerow(["token", "count"])
        for tok, freq in sorted(counter.items(), key=lambda kv: (-kv[1], kv[0])):
            w.writerow([tok, freq])

# ---- run ----
records = load_records(PATH)

for field in FIELDS:
    texts = collect_texts(records, field)
    counts = count_tokens_nltk(texts)
    outfile = OUTDIR / f"{field}__unigrams_nltk.csv"
    save_counts_csv(counts, outfile)

# %% [markdown]
# ### Visualize the frequency ###

# %%
def load_records(path: pathlib.Path):
    txt = path.read_text(encoding="utf-8")
    try:
        obj = json.loads(txt)
    except json.JSONDecodeError:
        # JSONL fallback
        recs = []
        with path.open(encoding="utf-8") as f:
            for line in f:
                line = line.strip()
                if line:
                    recs.append(json.loads(line))
        return recs
    if isinstance(obj, list):
        return obj
    if isinstance(obj, dict):
        if "contests" in obj and isinstance(obj["contests"], list):
            return obj["contests"]
        return [obj]
    raise ValueError("Unsupported JSON structure")

def collect_texts(records, field: str) -> List[str]:
    out = []
    for r in records:
        m = r.get("metadata") or {}
        v = m.get(field) if isinstance(m, dict) else None
        if isinstance(v, list):
            out.extend([s for s in v if isinstance(s, str)])
        elif isinstance(v, str):
            out.append(v)
    return out

# --- Run per field ---
records = load_records(PATH)

for field in FIELDS:
    texts = collect_texts(records, field)
    if not texts:
        print(f"[{field}] No texts found, skipping.")
        continue

    vectorizer = CountVectorizer(
        stop_words="english",
        token_pattern=r"(?u)\b[a-zA-Z]{3,}\b",
        ngram_range=NGRAM_RANGE
    )
    X = vectorizer.fit_transform(texts)               # sparse [n_docs, n_vocab]
    counts = np.asarray(X.sum(axis=0)).ravel()        # total counts per vocab term
    vocab = np.array(vectorizer.get_feature_names_out())

    # sort by frequency desc, then term asc
    order = np.lexsort((vocab, -counts))
    top_idx = order[:TOP_K]
    top_terms = vocab[top_idx]
    top_counts = counts[top_idx]

    # Plot one figure per field
    plt.figure(figsize=(12, 5))
    plt.bar(top_terms, top_counts)
    plt.xticks(rotation=90)
    ngram_label = "unigrams" if NGRAM_RANGE == (1,1) else f"{NGRAM_RANGE[0]}-{NGRAM_RANGE[1]}-grams"
    plt.title(f"Top {TOP_K} {ngram_label} — {field}")
    plt.ylabel("Frequency")
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ### Visualize the clusters ###

# %%
# --- Config ---
PATH = pathlib.Path("data/newyorker_caption_contest/contests.json")
FIELDS = ["image_descriptions", "image_uncanny_descriptions", "image_locations", "questions"]
MAX_FEATURES = 5000
DEFAULT_NUM_CLUSTERS = 20
MIN_DOCS_FOR_CLUSTERING = 10      # skip clustering if fewer docs than this
TOP_TERMS_PER_CLUSTER = 10        # how many top words to show per cluster
RANDOM_STATE = 42

# --- Load & normalize JSON ---
def load_records(path: pathlib.Path):
    txt = path.read_text(encoding="utf-8")
    try:
        obj = json.loads(txt)
    except json.JSONDecodeError:
        recs = []
        with path.open(encoding="utf-8") as f:
            for line in f:
                line = line.strip()
                if line:
                    recs.append(json.loads(line))
        return recs
    if isinstance(obj, list):
        return obj
    if isinstance(obj, dict):
        if "contests" in obj and isinstance(obj["contests"], list):
            return obj["contests"]
        return [obj]
    raise ValueError("Unsupported JSON structure")

def collect_texts(records, field: str) -> List[str]:
    out = []
    for r in records:
        m = r.get("metadata") or {}
        v = m.get(field) if isinstance(m, dict) else None
        if isinstance(v, list):
            out.extend([s for s in v if isinstance(s, str)])
        elif isinstance(v, str):
            out.append(v)
    # basic cleanup: strip; drop empty
    out = [t.strip() for t in out if isinstance(t, str) and t.strip()]
    return out

def fit_tfidf(texts: List[str]) -> Tuple[TfidfVectorizer, np.ndarray]:
    vec = TfidfVectorizer(
        stop_words="english",
        max_features=MAX_FEATURES,
        token_pattern=r"(?u)\b[a-zA-Z]{3,}\b",  # words with >=3 letters
    )
    X = vec.fit_transform(texts)  # sparse matrix
    return vec, X

def auto_num_clusters(n_docs: int) -> int:
    # heuristic: up to DEFAULT_NUM_CLUSTERS, but never more than n_docs//5 and at least 2
    k = min(DEFAULT_NUM_CLUSTERS, max(2, n_docs // 5))
    return min(k, n_docs) if n_docs >= 2 else 0

def top_terms_per_cluster(kmeans: KMeans, vectorizer: TfidfVectorizer, top_n: int = 10):
    # approximate interpretability: use cluster centers to pick top-weighted features
    terms = vectorizer.get_feature_names_out()
    centers = kmeans.cluster_centers_
    for i, c in enumerate(centers):
        top_idx = np.argsort(c)[::-1][:top_n]
        yield i, [terms[j] for j in top_idx]

def plot_clusters_2d(X_sparse, labels, title: str):
    svd = TruncatedSVD(n_components=2, random_state=RANDOM_STATE)
    X_2d = svd.fit_transform(X_sparse)  # works on sparse
    plt.figure(figsize=(10, 5))
    plt.scatter(X_2d[:, 0], X_2d[:, 1], c=labels, s=6, cmap="viridis")
    plt.title(title)
    plt.xlabel("SVD component 1")
    plt.ylabel("SVD component 2")
    plt.tight_layout()
    plt.show()

# --- Run per field ---
records = load_records(PATH)

for field in FIELDS:
    texts = collect_texts(records, field)
    n_docs = len(texts)
    if n_docs < MIN_DOCS_FOR_CLUSTERING:
        print(f"[{field}] Not enough documents ({n_docs}) — skipping clustering.")
        continue

    vectorizer, X_tfidf = fit_tfidf(texts)
    k = auto_num_clusters(n_docs)
    if k < 2:
        print(f"[{field}] Not enough documents for clustering — skipping.")
        continue

    kmeans = KMeans(n_clusters=k, random_state=RANDOM_STATE, n_init=10)
    kmeans.fit(X_tfidf)
    labels = kmeans.labels_

    # Print top terms per cluster (interpretation)
    print(f"\n=== {field} — KMeans(k={k}) top terms per cluster ===")
    for cid, terms in top_terms_per_cluster(kmeans, vectorizer, TOP_TERMS_PER_CLUSTER):
        print(f"Cluster {cid:02d}: {', '.join(terms)}")

    # Plot 2D clusters
    plot_clusters_2d(X_tfidf, labels, f"{field} — KMeans clusters (k={k})")
# Out:
# === image_descriptions — KMeans(k=20) top terms per cluster ===
# Cluster 00: kitchen, cooking, hazmat, traps, knight, suit, mess, locked, tight, stove
# Cluster 01: couch, nearby, dog, room, sitting, hot, man, living, people, monkeys
# Cluster 02: cave, caveman, cup, coffee, hole, modern, shop, talking, china, cavepeople
# Cluster 03: room, living, sitting, man, going, woman, train, chair, women, throne
# Cluster 04: holding, standing, like, face, man, looks, worried, look, cloud, woman
# Cluster 05: doctor, patient, gingerbread, king, wrapped, snake, examination, man, office, hospital
# Cluster 06: men, walking, carrying, man, woman, street, briefcase, island, building, business
# Cluster 07: maze, mouse, lab, mice, scientists, scientist, head, computers, mounted, snail
# Cluster 08: fish, bar, bartender, dumpty, humpty, talking, offers, alcohol, plaque, beer
# Cluster 09: looking, outside, window, people, man, house, woman, couple, talking, store
# Cluster 10: office, psychiatrist, desk, talking, couch, therapist, man, patient, sword, notes
# Cluster 11: hair, tower, man, looks, rapunzel, shock, long, phone, barber, like
# Cluster 12: man, mountain, climbing, staring, leaves, old, piano, cat, huge, sitting
# Cluster 13: man, woman, sitting, table, watching, door, look, king, store, opening
# Cluster 14: conversation, having, man, appear, skeleton, coffins, eye, deer, coffin, cemetery
# Cluster 15: boy, man, standing, dog, wearing, sharks, angry, genie, right, talking
# Cluster 16: people, whale, subway, car, station, island, waiting, train, waiter, having
# Cluster 17: restaurant, table, waiter, menu, sitting, man, dinner, soup, eating, reading
# Cluster 18: cliff, hiking, hikers, mountains, edge, watch, walking, man, cars, nature
# Cluster 19: party, bunch, woman, people, drunk, approaching, astronaut, talking, drink, diver
# === image_uncanny_descriptions — KMeans(k=20) top terms per cluster ===
# Cluster 00: alive, looking, gingerbread, chefs, hospital, man, doctors, trees, smiling, beast
# Cluster 01: people, middle, water, car, build, dog, shouldn, outside, thing, normally
# Cluster 02: usually, standing, shark, humans, don, person, stand, close, upright, dragons
# Cluster 03: giant, does, lizard, belong, paper, insects, unusual, enormous, sun, donut
# Cluster 04: men, dozen, tiny, tubas, possible, bathroom, elevator, look, lay, watching
# Cluster 05: earth, pinata, angels, aliens, communicating, carries, globe, playing, lot, oxygen
# Cluster 06: large, unusual, lady, halo, balls, aren, unusually, beach, compared, satan
# Cluster 07: man, head, mountain, like, lion, cannonballing, pool, piano, looks, diving
# Cluster 08: place, really, office, stands, ufos, traps, image, sword, picture, anchor
# Cluster 09: modern, woman, times, knight, kitchen, caveman, man, carrying, supposed, mosquitoes
# Cluster 10: table, subway, station, waiter, restaurant, larger, middle, unusual, menu, far
# Cluster 11: time, period, belong, modern, wrong, don, knight, woman, doesn, jacket
# Cluster 12: unusual, inside, room, living, people, man, house, office, sheep, animals
# Cluster 13: don, exist, size, snails, fish, use, people, walk, lizards, big
# Cluster 14: human, giraffes, things, doing, mosquito, sized, magician, fish, like, people
# Cluster 15: odd, death, magic, client, alley, baker, die, act, rocks, stacked
# Cluster 16: like, king, dressed, looks, cacti, dress, don, unusual, window, sword
# Cluster 17: wear, instead, shoes, clothes, horses, suits, wearing, horse, don, people
# Cluster 18: huge, snow, man, snake, course, shovel, golf, tiny, playing, pool
# Cluster 19: wearing, city, upright, hat, clothing, clothes, size, bed, background, man
# === image_locations — KMeans(k=20) top terms per cluster ===
# Cluster 00: bar, funeral, hard, hamster, hall, ground, grocery, graveyard, golf, gas
# Cluster 01: field, party, forest, castle, ship, meeting, yard, sea, beach, kingdom
# Cluster 02: cave, dwelling, yoga, gallery, hard, hamster, hall, ground, grocery, graveyard
# Cluster 03: restaurant, yoga, funeral, hamster, hall, ground, grocery, graveyard, golf, gas
# Cluster 04: room, living, forest, hamster, hall, ground, grocery, graveyard, golf, gas
# Cluster 05: desert, middle, funeral, hard, hamster, hall, ground, grocery, graveyard, golf
# Cluster 06: backyard, yoga, funeral, hard, hamster, hall, ground, grocery, graveyard, golf
# Cluster 07: building, ledge, office, yoga, funeral, hamster, hall, ground, grocery, graveyard
# Cluster 08: sidewalk, yoga, forest, hamster, hall, ground, grocery, graveyard, golf, gas
# Cluster 09: park, bench, public, heaven, hard, hamster, hall, ground, grocery, graveyard
# Cluster 10: subway, train, station, yoga, hard, hall, ground, grocery, graveyard, golf
# Cluster 11: courtroom, yoga, funeral, hard, hamster, hall, ground, grocery, graveyard, golf
# Cluster 12: elevator, yoga, gallery, hard, hamster, hall, ground, grocery, graveyard, golf
# Cluster 13: ocean, yoga, funeral, hard, hamster, hall, ground, grocery, graveyard, golf
# Cluster 14: rooftop, yoga, funeral, hamster, hall, ground, grocery, graveyard, golf, gas
# Cluster 15: mountain, ridge, yoga, funeral, hamster, hall, ground, grocery, graveyard, golf
# Cluster 16: office, doctor, therapist, room, psychiatry, police, psychiatrist, psychologist, desk, corporate
# Cluster 17: island, small, yoga, funeral, hall, ground, grocery, graveyard, golf, gas
# Cluster 18: kitchen, yoga, hard, hamster, hall, ground, grocery, graveyard, golf, gas
# Cluster 19: door, heaven, hard, hamster, hall, ground, grocery, graveyard, golf, gas
# === questions — KMeans(k=20) top terms per cluster ===
# Cluster 00: built, washing, machines, tracks, house, stacked, pair, look, apartment, like
# Cluster 01: cowboy, saying, far, falling, fall, faces, face, fable, explorer, explain
# Cluster 02: using, office, sword, holding, man, desk, computers, person, embedded, ivs
# Cluster 03: big, snail, city, hornets, menu, sword, waiter, head, attacking, gigantic
# Cluster 04: wearing, like, dressed, person, dog, armor, horse, suit, propeller, woman
# Cluster 05: going, king, color, doctor, building, bear, men, whale, caveman, cooking
# Cluster 06: trying, room, living, baseball, hit, playing, hatch, row, man, slanted
# Cluster 07: man, gingerbread, head, isn, mountain, dead, happy, cat, small, sandbox
# Cluster 08: does, head, say, want, blender, long, man, hair, need, face
# Cluster 09: saying, man, woman, caveman, waiter, employee, turtle, hiker, genie, horse
# Cluster 10: angry, sheep, lizard, plaque, wolves, fish, experiment, fall, faces, face
# Cluster 11: did, man, come, build, choose, intelligent, guy, whale, chef, door
# Cluster 12: doing, dolphins, man, farmer, bathtub, purpose, adults, vendor, snowman, alligator
# Cluster 13: talking, bartender, turtle, mouse, family, falling, fall, faces, face, fable
# Cluster 14: huge, man, carrying, snake, mosquitoes, frill, umbrella, dogs, sword, halo
# Cluster 15: people, just, watching, inside, burning, tiny, dealing, cannonballing, corner, bubbles
# Cluster 16: house, giraffes, piano, golf, monkeys, ruler, tangled, dropped, did, space
# Cluster 17: shop, china, bull, coffee, anchor, inspecting, weird, giant, acting, glass
# Cluster 18: happened, fish, alive, plaque, mounted, groomsman, leg, death, city, tattered
# Cluster 19: grilling, train, subway, man, embedded, employee, egotistical, fall, faces, face

# %% [markdown]
# ### Extract google trend data from march 2016 to september 2023

# %%
# === Google Trends for ALL tokens from your four CSVs ===

# ---------- CONFIG ----------
CSV_DIR = Path("data/GoogleTrends/frequent_words")
FIELD_PREFIXES = [
    "image_descriptions",
    "image_uncanny_descriptions",
    "image_locations",
    "questions",
]
# We'll read ANY CSV that starts with one of the prefixes (so works with both nltk/non-nltk filenames)
TIMEFRAME = "2016-03-01 2023-09-30"   # March 2016 → September 2023
GEO = "US"                            # set "" for worldwide
BATCH_SIZE = 5                        # Google Trends limit per request
SLEEP_SEC = 2.0                       # politeness delay between calls
RETRY = 2                             # retry per batch on transient errors
MIN_TOKEN_LEN = 3                     # ignore ultra-short tokens
SAVE_PATH = Path("data/GoogleTrends/google_trends_ALL_tokens_2016_03_to_2023_09_US.csv")
# ----------------------------

def read_tokens_from_csvs(csv_dir: Path, prefixes):
    tokens = []
    for pref in prefixes:
        for p in csv_dir.glob(f"{pref}__*.csv"):
            df = pd.read_csv(p)
            if "token" not in df.columns:
                continue
            toks = (
                df["token"]
                .astype(str)
                .map(str.strip)
                .replace("", np.nan)
                .dropna()
                .tolist()
            )
            tokens.extend(toks)
    # de-duplicate preserving order; enforce min length
    seen = set()
    result = []
    for t in tokens:
        t_low = t.lower()
        if len(t_low) >= MIN_TOKEN_LEN and t_low not in seen:
            seen.add(t_low)
            result.append(t)
    return result

def chunks(lst, n):
    for i in range(0, len(lst), n):
        yield lst[i : i + n]

# 1) Collect ALL tokens
keywords = read_tokens_from_csvs(CSV_DIR, FIELD_PREFIXES)
if not keywords:
    raise ValueError(f"No tokens found in {CSV_DIR} for prefixes {FIELD_PREFIXES}")

print(f"Total unique keywords to fetch: {len(keywords)}")

# 2) Query Google Trends in batches (≤5)
pytrends = TrendReq(hl="en-US", tz=360)
frames = []
failed_batches = []

for batch in chunks(keywords, BATCH_SIZE):
    ok = False
    err = None
    for attempt in range(1, RETRY + 2):  # first try + retries
        try:
            pytrends.build_payload(kw_list=batch, timeframe=TIMEFRAME, geo=GEO)
            df = pytrends.interest_over_time()
            if "isPartial" in df.columns:
                df = df.drop(columns=["isPartial"])
            frames.append(df)
            ok = True
            break
        except Exception as e:
            err = e
            time.sleep(SLEEP_SEC * attempt)  # exponential-ish backoff
    if not ok:
        failed_batches.append((batch, repr(err)))
    time.sleep(SLEEP_SEC)

# 3) Merge results
if not frames:
    raise RuntimeError("No data returned from Google Trends. (All batches failed.)")

trends_wide = frames[0]
for df in frames[1:]:
    trends_wide = trends_wide.join(df, how="outer")

# Sort by date and fill missing with 0 (optional)
trends_wide = trends_wide.sort_index().fillna(0).astype(int)

# 4) Save single CSV (one column per keyword)
SAVE_PATH.parent.mkdir(parents=True, exist_ok=True)
trends_wide.to_csv(SAVE_PATH)
print(f"Saved trends to: {SAVE_PATH.resolve()}  with shape {trends_wide.shape}")

# 5) Minimal report on failures (if any)
if failed_batches:
    print("\nSome batches failed (columns missing for these keywords):")
    for batch, e in failed_batches:
        print(f"- {batch} -> {e}")

# 6) Quick sanity peek (first 5 columns & rows)
display(trends_wide.iloc[:5, :5])
# Out:
# Total unique keywords to fetch: 2263
# Saved trends to: /Users/tharabelin/Desktop/ADA/ada-2025-project-data_dinosaur/data/GoogleTrends/google_trends_ALL_tokens_2016_03_to_2023_09_US.csv  with shape (91, 508)
#
# Some batches failed (columns missing for these keywords):
# - ['man', 'two', 'woman', 'people', 'one'] -> TooManyRequestsError('The request failed: Google returned a response with code 429')
# - ['sitting', 'talking', 'looking', 'standing', 'looks'] -> TooManyRequestsError('The request failed: Google returned a response with code 429')
# - ['room', 'men', 'another', 'table', 'couple'] -> TooManyRequestsError('The request failed: Google returned a response with code 429')
# - ['giant', 'look', 'office', 'wearing', 'front'] -> TooManyRequestsError('The request failed: Google returned a response with code 429')
# - ['holding', 'outside', 'walking', 'around', 'inside'] -> TooManyRequestsError('The request failed: Google returned a response with code 429')
# - ['huge', 'behind', 'restaurant', 'watching', 'face'] -> TooManyRequestsError('The request failed: Google returned a response with code 429')
# - ['living', 'staring', 'doctor', 'couch', 'next'] -> TooManyRequestsError('The request failed: Google returned a response with code 429')
# - ['three', 'top', 'dog', 'head', 'person'] -> TooManyRequestsError('The request failed: Google returned a response with code 429')
# - ['waiter', 'bunch', 'carrying', 'caveman', 'large'] -> TooManyRequestsError('The request failed: Google returned a response with code 429')
# - ['like', 'king', 'cave', 'fish', 'house'] -> TooManyRequestsError('The request failed: Google returned a response with code 429')
# - ['angry', 'bar', 'door', 'ground', 'island'] -> TooManyRequestsError('The request failed: Google returned a response with code 429')
# - ['appears', 'boy', 'middle', 'building', 'car'] -> TooManyRequestsError('The request failed: Google returned a response with code 429')
# - ['desert', 'facing', 'hand', 'kitchen', 'knight'] -> TooManyRequestsError('The request failed: Google returned a response with code 429')
# - ['paper', 'phone', 'see', 'store', 'together'] -> TooManyRequestsError('The request failed: Google returned a response with code 429')
# - ['back', 'chair', 'coming', 'hair', 'happy'] -> TooManyRequestsError('The request failed: Google returned a response with code 429')
# - ['horse', 'nearby', 'patient', 'suit', 'wall'] -> TooManyRequestsError('The request failed: Google returned a response with code 429')
# - ['window', 'cat', 'dressed', 'meeting', 'mountain'] -> TooManyRequestsError('The request failed: Google returned a response with code 429')
# - ['playing', 'reading', 'sits', 'small', 'someone'] -> TooManyRequestsError('The request failed: Google returned a response with code 429')
# - ['stands', 'bear', 'city', 'conversation', 'counter'] -> TooManyRequestsError('The request failed: Google returned a response with code 429')
# - ['drink', 'expression', 'group', 'right', 'sharks'] -> TooManyRequestsError('The request failed: Google returned a response with code 429')
# - ['sheep', 'side', 'subway', 'taking', 'train'] -> TooManyRequestsError('The request failed: Google returned a response with code 429')
# - ['water', 'whale', 'animals', 'background', 'bird'] -> TooManyRequestsError('The request failed: Google returned a response with code 429')
# - ['climbing', 'clothes', 'desk', 'dinner', 'going'] -> TooManyRequestsError('The request failed: Google returned a response with code 429')
# - ['hat', 'hole', 'lab', 'laying', 'leaves'] -> TooManyRequestsError('The request failed: Google returned a response with code 429')
# - ['mouth', 'seems', 'shop', 'snow', 'surrounded'] -> TooManyRequestsError('The request failed: Google returned a response with code 429')
# - ['towards', 'waiting', 'wine', 'across', 'also'] -> TooManyRequestsError('The request failed: Google returned a response with code 429')
# - ['baseball', 'cooking', 'dogs', 'drinking', 'long'] -> TooManyRequestsError('The request failed: Google returned a response with code 429')
# - ['maze', 'menu', 'observing', 'park', 'party'] -> TooManyRequestsError('The request failed: Google returned a response with code 429')
# - ['piano', 'police', 'running', 'seated', 'speaking'] -> TooManyRequestsError('The request failed: Google returned a response with code 429')
# - ['stares', 'throne', 'tower', 'tree', 'trying'] -> TooManyRequestsError('The request failed: Google returned a response with code 429')
# - ['women', 'air', 'appear', 'bartender', 'board'] -> TooManyRequestsError('The request failed: Google returned a response with code 429')
# - ['business', 'cake', 'clothing', 'clouds', 'crawling'] -> TooManyRequestsError('The request failed: Google returned a response with code 429')
# - ['deer', 'drinks', 'earth', 'elevator', 'floor'] -> TooManyRequestsError('The request failed: Google returned a response with code 429')
# - ['food', 'genie', 'making', 'mouse', 'ocean'] -> TooManyRequestsError('The request failed: Google returned a response with code 429')
# - ['officer', 'old', 'order', 'riding', 'ship'] -> TooManyRequestsError('The request failed: Google returned a response with code 429')
# - ['shocked', 'showing', 'sidewalk', 'stare', 'station'] -> TooManyRequestsError('The request failed: Google returned a response with code 429')
# - ['suits', 'watches', 'way', 'arms', 'boat'] -> TooManyRequestsError('The request failed: Google returned a response with code 429')
# - ['cliff', 'cloud', 'clown', 'coffee', 'computer'] -> TooManyRequestsError('The request failed: Google returned a response with code 429')
# - ['confused', 'foreground', 'glass', 'high', 'judge'] -> TooManyRequestsError('The request failed: Google returned a response with code 429')
# - ['legs', 'mice', 'needle', 'number', 'open'] -> TooManyRequestsError('The request failed: Google returned a response with code 429')
# - ['piece', 'pirates', 'plane', 'psychiatrist', 'rat'] -> TooManyRequestsError('The request failed: Google returned a response with code 429')
# - ['snake', 'sofa', 'something', 'stand', 'still'] -> TooManyRequestsError('The request failed: Google returned a response with code 429')
# - ['street', 'stuck', 'sword', 'therapist', 'tied'] -> TooManyRequestsError('The request failed: Google returned a response with code 429')
# - ['tiny', 'wheel', 'worried', 'aliens', 'angel'] -> TooManyRequestsError('The request failed: Google returned a response with code 429')
# - ['angels', 'astronaut', 'away', 'big', 'briefcase'] -> TooManyRequestsError('The request failed: Google returned a response with code 429')
# - ['castle', 'ceiling', 'child', 'covered', 'cup'] -> TooManyRequestsError('The request failed: Google returned a response with code 429')
# - ['customers', 'dragon', 'eating', 'employee', 'field'] -> TooManyRequestsError('The request failed: Google returned a response with code 429')
# - ['fire', 'flying', 'full', 'giraffe', 'giraffes'] -> TooManyRequestsError('The request failed: Google returned a response with code 429')
# - ['grill', 'hammock', 'hamster', 'hanging', 'hikers'] -> TooManyRequestsError('The request failed: Google returned a response with code 429')
# - ['jack', 'lawyer', 'left', 'lizard', 'mounted'] -> TooManyRequestsError('The request failed: Google returned a response with code 429')
# - ['near', 'pirate', 'place', 'plank', 'pool'] -> TooManyRequestsError('The request failed: Google returned a response with code 429')
# - ['scene', 'scientist', 'scientists', 'seem', 'snail'] -> TooManyRequestsError('The request failed: Google returned a response with code 429')
# - ['soup', 'surprised', 'third', 'tracks', 'tries'] -> TooManyRequestsError('The request failed: Google returned a response with code 429')
# - ['upset', 'walks', 'working', 'yoga', 'alligator'] -> TooManyRequestsError('The request failed: Google returned a response with code 429')
# - ['animal', 'art', 'baker', 'barber', 'beach'] -> TooManyRequestsError('The request failed: Google returned a response with code 429')
# - ['beanstalk', 'bed', 'beer', 'beside', 'birds'] -> TooManyRequestsError('The request failed: Google returned a response with code 429')
# - ['body', 'bowl', 'bull', 'chatting', 'chef'] -> TooManyRequestsError('The request failed: Google returned a response with code 429')
# - ['church', 'computers', 'cowboy', 'cowboys', 'crown'] -> TooManyRequestsError('The request failed: Google returned a response with code 429')
# - ['destroyed', 'distance', 'drawing', 'drunk', 'dwarfs'] -> TooManyRequestsError('The request failed: Google returned a response with code 429')
# - ['egg', 'end', 'entire', 'game', 'get'] -> TooManyRequestsError('The request failed: Google returned a response with code 429')
# - ['gingerbread', 'giving', 'grim', 'guard', 'heads'] -> TooManyRequestsError('The request failed: Google returned a response with code 429')
# - ['home', 'hot', 'hunter', 'knife', 'lady'] -> TooManyRequestsError('The request failed: Google returned a response with code 429')
# - ['lamp', 'lion', 'little', 'magician', 'modern'] -> TooManyRequestsError('The request failed: Google returned a response with code 429')
# - ['mosquito', 'normal', 'organ', 'pigeon', 'pizza'] -> TooManyRequestsError('The request failed: Google returned a response with code 429')
# - ['planets', 'policeman', 'pouring', 'pulling', 'pushing'] -> TooManyRequestsError('The request failed: Google returned a response with code 429')
# - ['rabbit', 'raking', 'rapunzel', 'reaper', 'relaxing'] -> TooManyRequestsError('The request failed: Google returned a response with code 429')
# - ['road', 'sandbox', 'shock', 'shopping', 'signs'] -> TooManyRequestsError('The request failed: Google returned a response with code 429')
# - ['snowman', 'straight', 'suspenders', 'tattered', 'tie'] -> TooManyRequestsError('The request failed: Google returned a response with code 429')
# - ['toaster', 'traps', 'tub', 'underwater', 'waving'] -> TooManyRequestsError('The request failed: Google returned a response with code 429')
# - ['weight', 'windows', 'witness', 'wolf', 'wolves'] -> TooManyRequestsError('The request failed: Google returned a response with code 429')
# - ['wrapped', 'adults', 'alcohol', 'alley', 'along'] -> TooManyRequestsError('The request failed: Google returned a response with code 429')
# - ['anchor', 'approaching', 'armor', 'attached', 'attacked'] -> TooManyRequestsError('The request failed: Google returned a response with code 429')
# - ['attire', 'bat', 'beached', 'bench', 'blender'] -> TooManyRequestsError('The request failed: Google returned a response with code 429')
# - ['blindfolded', 'block', 'booth', 'brush', 'cactus'] -> TooManyRequestsError('The request failed: Google returned a response with code 429')
# - ['cavemen', 'cavepeople', 'cement', 'chart', 'chefs'] -> TooManyRequestsError('The request failed: Google returned a response with code 429')
# - ['cherry', 'chest', 'china', 'clerk', 'club'] -> TooManyRequestsError('The request failed: Google returned a response with code 429')
# - ['coffins', 'come', 'comes', 'completely', 'corner'] -> TooManyRequestsError('The request failed: Google returned a response with code 429')
# - ['courtroom', 'crime', 'date', 'death', 'deep'] -> TooManyRequestsError('The request failed: Google returned a response with code 429')
# - ['dinosaur', 'dive', 'diver', 'dolphins', 'drones'] -> TooManyRequestsError('The request failed: Google returned a response with code 429')
# - ['dumpty', 'edge', 'elephant', 'employees', 'empty'] -> TooManyRequestsError('The request failed: Google returned a response with code 429')
# - ['everyone', 'examination', 'faces', 'far', 'filled'] -> TooManyRequestsError('The request failed: Google returned a response with code 429')
# - ['flowers', 'gas', 'gear', 'getting', 'glasses'] -> TooManyRequestsError('The request failed: Google returned a response with code 429')
# - ['golf', 'gun', 'hall', 'hands', 'happening'] -> TooManyRequestsError('The request failed: Google returned a response with code 429')
# - ['hazmat', 'hiking', 'horses', 'hospital', 'human'] -> TooManyRequestsError('The request failed: Google returned a response with code 429')
# - ['humpty', 'kites', 'lawn', 'leading', 'line'] -> TooManyRequestsError('The request failed: Google returned a response with code 429')
# - ['listening', 'locked', 'lounging', 'many', 'medieval'] -> TooManyRequestsError('The request failed: Google returned a response with code 429')
# - ['mess', 'mobster', 'monkeys', 'moon', 'museum'] -> TooManyRequestsError('The request failed: Google returned a response with code 429')
# - ['music', 'neck', 'necks', 'notes', 'nothing'] -> TooManyRequestsError('The request failed: Google returned a response with code 429')
# - ['offering', 'onto', 'opening', 'others', 'outlines'] -> TooManyRequestsError('The request failed: Google returned a response with code 429')
# - ['palm', 'path', 'phones', 'points', 'possibly'] -> TooManyRequestsError('The request failed: Google returned a response with code 429')
# - ['priest', 'princess', 'ready', 'realtor', 'robe'] -> TooManyRequestsError('The request failed: Google returned a response with code 429')
# - ['rock', 'rug', 'saying', 'seen', 'serious'] -> TooManyRequestsError('The request failed: Google returned a response with code 429')
# - ['set', 'shaped', 'shepherd', 'shirt', 'shoes'] -> TooManyRequestsError('The request failed: Google returned a response with code 429')
# - ['shredder', 'sit', 'situation', 'size', 'skeleton'] -> TooManyRequestsError('The request failed: Google returned a response with code 429')
# - ['sky', 'snowmen', 'sound', 'stacked', 'stove'] -> TooManyRequestsError('The request failed: Google returned a response with code 429')
# - ['strapped', 'studio', 'swimming', 'tall', 'teddy'] -> TooManyRequestsError('The request failed: Google returned a response with code 429')
# - ['though', 'trees', 'turtle', 'ufo', 'unicorn'] -> TooManyRequestsError('The request failed: Google returned a response with code 429')
# - ['uniform', 'vendor', 'waits', 'walk', 'watch'] -> TooManyRequestsError('The request failed: Google returned a response with code 429')
# - ['wedding', 'well', 'werewolf', 'wet', 'white'] -> TooManyRequestsError('The request failed: Google returned a response with code 429')
# - ['yard', 'accident', 'adam', 'addressing', 'admiring'] -> TooManyRequestsError('The request failed: Google returned a response with code 429')
# - ['amish', 'ankle', 'anthropomorphic', 'approached', 'approaches'] -> TooManyRequestsError('The request failed: Google returned a response with code 429')
# - ['archer', 'assistant', 'atop', 'backseat', 'badge'] -> TooManyRequestsError('The request failed: Google returned a response with code 429')
# - ['balcony', 'ball', 'band', 'barbecue', 'bath'] -> TooManyRequestsError('The request failed: Google returned a response with code 429')
# - ['beachball', 'beam', 'bicycle', 'bike', 'binoculars'] -> TooManyRequestsError('The request failed: Google returned a response with code 429')
# - ['biting', 'blonde', 'book', 'bottom', 'boulder'] -> TooManyRequestsError('The request failed: Google returned a response with code 429')
# - ['box', 'branch', 'bucket', 'buildings', 'burger'] -> TooManyRequestsError('The request failed: Google returned a response with code 429')
# - ['busy', 'butler', 'cacti', 'calm', 'cannonball'] -> TooManyRequestsError('The request failed: Google returned a response with code 429')
# - ['cap', 'carry', 'cart', 'carts', 'cavewoman'] -> TooManyRequestsError('The request failed: Google returned a response with code 429')
# - ['cell', 'cemetery', 'chairs', 'cheese', 'claws'] -> TooManyRequestsError('The request failed: Google returned a response with code 429')
# - ['climbs', 'clones', 'coat', 'coats', 'coffin'] -> TooManyRequestsError('The request failed: Google returned a response with code 429')
# - ['collar', 'colored', 'colorful', 'concerned', 'confronting'] -> TooManyRequestsError('The request failed: Google returned a response with code 429')
# - ['cop', 'court', 'creature', 'crossed', 'cups'] -> TooManyRequestsError('The request failed: Google returned a response with code 429')
# - ['customer', 'deserted', 'detective', 'different', 'dining'] -> TooManyRequestsError('The request failed: Google returned a response with code 429')
# - ['dress', 'ducks', 'else', 'enough', 'eve'] -> TooManyRequestsError('The request failed: Google returned a response with code 429')
# - ['everything', 'everywhere', 'executives', 'experimenting', 'explorers'] -> TooManyRequestsError('The request failed: Google returned a response with code 429')
# - ['expressions', 'eye', 'facial', 'falling', 'fancy'] -> TooManyRequestsError('The request failed: Google returned a response with code 429')
# - ['father', 'fear', 'feet', 'find', 'finds'] -> TooManyRequestsError('The request failed: Google returned a response with code 429')
# - ['fins', 'forest', 'frankenstein', 'free', 'frowning'] -> TooManyRequestsError('The request failed: Google returned a response with code 429')
# - ['garbage', 'gathered', 'gecko', 'girl', 'globe'] -> TooManyRequestsError('The request failed: Google returned a response with code 429')
# - ['groceries', 'grocery', 'guy', 'halo', 'hill'] -> TooManyRequestsError('The request failed: Google returned a response with code 429')
# - ['hind', 'hit', 'hood', 'horseback', 'houses'] -> TooManyRequestsError('The request failed: Google returned a response with code 429')
# - ['husband', 'identical', 'image', 'implied', 'including'] -> TooManyRequestsError('The request failed: Google returned a response with code 429')
# - ['inspecting', 'instead', 'instruments', 'interrupted', 'jackets'] -> TooManyRequestsError('The request failed: Google returned a response with code 429')
# - ['kite', 'laptop', 'leaning', 'ledge', 'leg'] -> TooManyRequestsError('The request failed: Google returned a response with code 429')
# - ['lobby', 'magic', 'make', 'makes', 'mannequin'] -> TooManyRequestsError('The request failed: Google returned a response with code 429')
# - ['marching', 'menus', 'midair', 'miniature', 'mirrored'] -> TooManyRequestsError('The request failed: Google returned a response with code 429')
# - ['mobile', 'model', 'monster', 'monstrous', 'mountains'] -> TooManyRequestsError('The request failed: Google returned a response with code 429')
# - ['mug', 'nature', 'nervous', 'note', 'notice'] -> TooManyRequestsError('The request failed: Google returned a response with code 429')
# - ['offers', 'ones', 'outfit', 'owner', 'pack'] -> TooManyRequestsError('The request failed: Google returned a response with code 429')
# - ['pancakes', 'pass', 'patron', 'peeking', 'pen'] -> TooManyRequestsError('The request failed: Google returned a response with code 429')
# - ['perusing', 'petting', 'picture', 'pilots', 'pinata'] -> TooManyRequestsError('The request failed: Google returned a response with code 429')
# - ['pipes', 'plaque', 'play', 'pleased', 'pointing'] -> TooManyRequestsError('The request failed: Google returned a response with code 429')
# - ['propeller', 'pulled', 'puts', 'putt', 'putting'] -> TooManyRequestsError('The request failed: Google returned a response with code 429')
# - ['radiator', 'red', 'register', 'replaced', 'reptile'] -> TooManyRequestsError('The request failed: Google returned a response with code 429')
# - ['repunzel', 'roof', 'rowing', 'runs', 'sam'] -> TooManyRequestsError('The request failed: Google returned a response with code 429')
# - ['satan', 'scissors', 'scribe', 'sea', 'seats'] -> TooManyRequestsError('The request failed: Google returned a response with code 429')
# - ['sees', 'served', 'serves', 'setting', 'setup'] -> TooManyRequestsError('The request failed: Google returned a response with code 429')
# - ['several', 'shark', 'shovel', 'shower', 'single'] -> TooManyRequestsError('The request failed: Google returned a response with code 429')
# - ['sized', 'skin', 'slanted', 'slippers', 'smaller'] -> TooManyRequestsError('The request failed: Google returned a response with code 429')
# - ['smiley', 'smiling', 'smoking', 'soldier', 'space'] -> TooManyRequestsError('The request failed: Google returned a response with code 429')
# - ['speaks', 'spikes', 'stabbed', 'stocks', 'stranded'] -> TooManyRequestsError('The request failed: Google returned a response with code 429')
# - ['stretches', 'string', 'sun', 'sweater', 'swimsuits'] -> TooManyRequestsError('The request failed: Google returned a response with code 429')
# - ['tables', 'takes', 'talk', 'thing', 'things'] -> TooManyRequestsError('The request failed: Google returned a response with code 429')
# - ['thread', 'ticket', 'tight', 'toast', 'tornado'] -> TooManyRequestsError('The request failed: Google returned a response with code 429')
# - ['toward', 'trapped', 'trick', 'truck', 'try'] -> TooManyRequestsError('The request failed: Google returned a response with code 429')
# - ['tuba', 'tubas', 'turned', 'type', 'umbrella'] -> TooManyRequestsError('The request failed: Google returned a response with code 429')
# - ['umpire', 'underground', 'uses', 'using', 'various'] -> TooManyRequestsError('The request failed: Google returned a response with code 429')
# - ['vehicle', 'waves', 'wheels', 'winking', 'work'] -> TooManyRequestsError('The request failed: Google returned a response with code 429')
# - ['workers', 'writing', 'yelling', 'acknowledging', 'act'] -> TooManyRequestsError('The request failed: Google returned a response with code 429')
# - ['adult', 'aggressive', 'aiming', 'aisle', 'alive'] -> TooManyRequestsError('The request failed: Google returned a response with code 429')
# - ['alligators', 'ally', 'alone', 'amphitheater', 'annoyed'] -> TooManyRequestsError('The request failed: Google returned a response with code 429')
# - ['anything', 'apartment', 'appeared', 'appearing', 'applauding'] -> TooManyRequestsError('The request failed: Google returned a response with code 429')
# - ['apprehension', 'approach', 'apron', 'asteroid', 'astronauts'] -> TooManyRequestsError('The request failed: Google returned a response with code 429')
# - ['attacking', 'attempting', 'attendant', 'attractive', 'author'] -> TooManyRequestsError('The request failed: Google returned a response with code 429')
# - ['baby', 'backpack', 'backpackers', 'backpacks', 'backyard'] -> TooManyRequestsError('The request failed: Google returned a response with code 429')
# - ['bakers', 'bald', 'balloon', 'banana', 'bandaged'] -> TooManyRequestsError('The request failed: Google returned a response with code 429')
# - ['bandages', 'banged', 'barbecuing', 'barbershop', 'barking'] -> TooManyRequestsError('The request failed: Google returned a response with code 429')
# - ['barrier', 'base', 'based', 'bathrobe', 'bathroom'] -> TooManyRequestsError('The request failed: Google returned a response with code 429')
# - ['bathtub', 'batter', 'battle', 'bbqing', 'beams'] -> TooManyRequestsError('The request failed: Google returned a response with code 429')
# - ['beard', 'bearded', 'beehive', 'belt', 'beneath'] -> TooManyRequestsError('The request failed: Google returned a response with code 429')
# - ['besides', 'beverage', 'bigfoot', 'bin', 'bit'] -> TooManyRequestsError('The request failed: Google returned a response with code 429')
# - ['black', 'blood', 'blue', 'blueprints', 'bodies'] -> TooManyRequestsError('The request failed: Google returned a response with code 429')
# - ['bonfire', 'books', 'bookstore', 'bored', 'boss'] -> TooManyRequestsError('The request failed: Google returned a response with code 429')
# - ['bothered', 'bottle', 'bounder', 'bow', 'boxed'] -> TooManyRequestsError('The request failed: Google returned a response with code 429')
# - ['boys', 'breakfast', 'bridesmaids', 'bringing', 'brings'] -> TooManyRequestsError('The request failed: Google returned a response with code 429')
# - ['broken', 'browsing', 'bubbles', 'bucked', 'buckets'] -> TooManyRequestsError('The request failed: Google returned a response with code 429')
# - ['bucking', 'build', 'built', 'burgers', 'burning'] -> TooManyRequestsError('The request failed: Google returned a response with code 429')
# - ['businessman', 'businessmen', 'button', 'bystanders', 'cafe'] -> TooManyRequestsError('The request failed: Google returned a response with code 429')
# - ['called', 'calling', 'calls', 'calmly', 'campfire'] -> TooManyRequestsError('The request failed: Google returned a response with code 429')
# - ['campsite', 'cannonballs', 'cape', 'cappuccino', 'cars'] -> TooManyRequestsError('The request failed: Google returned a response with code 429')
# - ['cashier', 'cast', 'casts', 'casual', 'casually'] -> TooManyRequestsError('The request failed: Google returned a response with code 429')
# - ['catcher', 'cats', 'caught', 'caved', 'cellphone'] -> TooManyRequestsError('The request failed: Google returned a response with code 429')
# - ['centaur', 'chained', 'chalk', 'chameleon', 'character'] -> TooManyRequestsError('The request failed: Google returned a response with code 429')
# - ['chased', 'cheating', 'checking', 'chewing', 'children'] -> TooManyRequestsError('The request failed: Google returned a response with code 429')
# - ['choking', 'cigar', 'cigarette', 'cinder', 'circular'] -> TooManyRequestsError('The request failed: Google returned a response with code 429')
# - ['classroom', 'cleaner', 'clear', 'clearly', 'client'] -> TooManyRequestsError('The request failed: Google returned a response with code 429')
# - ['climbed', 'clipboard', 'close', 'closer', 'cloth'] -> TooManyRequestsError('The request failed: Google returned a response with code 429')
# - ['clothed', 'clowns', 'coach', 'cocktail', 'coconut'] -> TooManyRequestsError('The request failed: Google returned a response with code 429')
# - ['columns', 'combine', 'commandments', 'commenting', 'communicator'] -> TooManyRequestsError('The request failed: Google returned a response with code 429')
# - ['companion', 'components', 'concert', 'concrete', 'conducting'] -> TooManyRequestsError('The request failed: Google returned a response with code 429')
# - ['conductor', 'cone', 'cones', 'conference', 'conferring'] -> TooManyRequestsError('The request failed: Google returned a response with code 429')
# - ['confusion', 'considers', 'construct', 'construction', 'contains'] -> TooManyRequestsError('The request failed: Google returned a response with code 429')
# - ['content', 'controlling', 'controls', 'conveyor', 'cook'] -> TooManyRequestsError('The request failed: Google returned a response with code 429')
# - ['cooked', 'cooks', 'corded', 'corpses', 'corral'] -> TooManyRequestsError('The request failed: Google returned a response with code 429')
# - ['costumes', 'couches', 'country', 'countryside', 'course'] -> TooManyRequestsError('The request failed: Google returned a response with code 429')
# - ['covering', 'cracked', 'crashed', 'crashing', 'creepily'] -> TooManyRequestsError('The request failed: Google returned a response with code 429')
# - ['crib', 'criminal', 'crook', 'crossing', 'crowded'] -> TooManyRequestsError('The request failed: Google returned a response with code 429')
# - ['crushed', 'cupboards', 'curator', 'curious', 'damaged'] -> TooManyRequestsError('The request failed: Google returned a response with code 429')
# - ['dance', 'dangling', 'day', 'deadly', 'debating'] -> TooManyRequestsError('The request failed: Google returned a response with code 429')
# - ['decided', 'deck', 'decorated', 'decreasingly', 'deeply'] -> TooManyRequestsError('The request failed: Google returned a response with code 429')
# - ['defending', 'defy', 'dejected', 'desks', 'destroying'] -> TooManyRequestsError('The request failed: Google returned a response with code 429')
# - ['detectives', 'devil', 'digging', 'dinosaurs', 'dip'] -> TooManyRequestsError('The request failed: Google returned a response with code 429')
# - ['disappear', 'disappointed', 'disappointment', 'disapproving', 'disassembled'] -> TooManyRequestsError('The request failed: Google returned a response with code 429')
# - ['disbelief', 'discussing', 'discussion', 'display', 'distant'] -> TooManyRequestsError('The request failed: Google returned a response with code 429')
# - ['diverse', 'diving', 'dolls', 'donut', 'dorsal'] -> TooManyRequestsError('The request failed: Google returned a response with code 429')
# - ['dough', 'dozen', 'dozens', 'dragging', 'dripping'] -> TooManyRequestsError('The request failed: Google returned a response with code 429')
# - ['driver', 'driving', 'drop', 'dropped', 'dryer'] -> TooManyRequestsError('The request failed: Google returned a response with code 429')
# - ['dueling', 'dummy', 'dungeon', 'eat', 'eden'] -> TooManyRequestsError('The request failed: Google returned a response with code 429')
# - ['embedded', 'encounter', 'engineers', 'england', 'enjoys'] -> TooManyRequestsError('The request failed: Google returned a response with code 429')
# - ['enormous', 'entangled', 'enter', 'entering', 'entwined'] -> TooManyRequestsError('The request failed: Google returned a response with code 429')
# - ['era', 'essentially', 'exact', 'examining', 'except'] -> TooManyRequestsError('The request failed: Google returned a response with code 429')
# - ['excited', 'executing', 'exercise', 'exhausted', 'exhibit'] -> TooManyRequestsError('The request failed: Google returned a response with code 429')
# - ['exiting', 'expecting', 'experiment', 'explorer', 'expressionless'] -> TooManyRequestsError('The request failed: Google returned a response with code 429')
# - ['extremely', 'eyeing', 'fall', 'fallen', 'family'] -> TooManyRequestsError('The request failed: Google returned a response with code 429')
# - ['famous', 'farmer', 'fashioned', 'fastened', 'fearful'] -> TooManyRequestsError('The request failed: Google returned a response with code 429')
# - ['female', 'fence', 'fenced', 'fending', 'fictional'] -> TooManyRequestsError('The request failed: Google returned a response with code 429')
# - ['fight', 'figure', 'figurines', 'filling', 'fin'] -> TooManyRequestsError('The request failed: Google returned a response with code 429')
# - ['finger', 'finished', 'firefighters', 'firehouse', 'fireplace'] -> TooManyRequestsError('The request failed: Google returned a response with code 429')
# - ['flanked', 'flooded', 'followed', 'following', 'four'] -> TooManyRequestsError('The request failed: Google returned a response with code 429')
# - ['fours', 'fourth', 'fridge', 'friend', 'fries'] -> TooManyRequestsError('The request failed: Google returned a response with code 429')
# - ['frightened', 'frill', 'funeral', 'furniture', 'gallery'] -> TooManyRequestsError('The request failed: Google returned a response with code 429')
# - ['garden', 'gate', 'gators', 'general', 'gentleman'] -> TooManyRequestsError('The request failed: Google returned a response with code 429')
# - ['gestures', 'gesturing', 'gets', 'glares', 'god'] -> TooManyRequestsError('The request failed: Google returned a response with code 429')
# - ['grab', 'grand', 'graph', 'graveyard', 'gravity'] -> TooManyRequestsError('The request failed: Google returned a response with code 429')
# - ['greek', 'green', 'greeting', 'grilling', 'grooms'] -> TooManyRequestsError('The request failed: Google returned a response with code 429')
# - ['guards', 'guitar', 'haircut', 'half', 'hallway'] -> TooManyRequestsError('The request failed: Google returned a response with code 429')
# - ['hamburger', 'handing', 'handled', 'hang', 'hangs'] -> TooManyRequestsError('The request failed: Google returned a response with code 429')
# - ['happened', 'hardly', 'hats', 'hauling', 'heading'] -> TooManyRequestsError('The request failed: Google returned a response with code 429')
# - ['headstones', 'held', 'helmets', 'help', 'helping'] -> TooManyRequestsError('The request failed: Google returned a response with code 429')
# - ['helps', 'hiding', 'highly', 'hiker', 'hindlegs'] -> TooManyRequestsError('The request failed: Google returned a response with code 429')
# - ['hitch', 'hitchhiker', 'hitchiking', 'hold', 'holds'] -> TooManyRequestsError('The request failed: Google returned a response with code 429')
# - ['homes', 'honey', 'hoodie', 'hooves', 'hornets'] -> TooManyRequestsError('The request failed: Google returned a response with code 429')
# - ['host', 'hosting', 'hotdog', 'hovered', 'hovering'] -> TooManyRequestsError('The request failed: Google returned a response with code 429')
# - ['however', 'hugging', 'humans', 'hunters', 'identification'] -> TooManyRequestsError('The request failed: Google returned a response with code 429')
# - ['ignores', 'imitate', 'impaled', 'impressive', 'indoor'] -> TooManyRequestsError('The request failed: Google returned a response with code 429')
# - ['injured', 'inquisitive', 'insects', 'inset', 'instructions'] -> TooManyRequestsError('The request failed: Google returned a response with code 429')
# - ['instructor', 'instrument', 'interracial', 'interrogating', 'interrupting'] -> TooManyRequestsError('The request failed: Google returned a response with code 429')
# - ['interrupts', 'introduced', 'inventory', 'irritated', 'irritation'] -> TooManyRequestsError('The request failed: Google returned a response with code 429')
# - ['ivs', 'jacket', 'jeans', 'jester', 'jet'] -> TooManyRequestsError('The request failed: Google returned a response with code 429')
# - ['jetpack', 'joggers', 'jousted', 'jumps', 'keys'] -> TooManyRequestsError('The request failed: Google returned a response with code 429')
# - ['kicked', 'kid', 'kids', 'kind', 'kings'] -> TooManyRequestsError('The request failed: Google returned a response with code 429')
# - ['knees', 'knifed', 'knights', 'ladies', 'lap'] -> TooManyRequestsError('The request failed: Google returned a response with code 429')
# - ['laptops', 'larger', 'lays', 'leader', 'leans'] -> TooManyRequestsError('The request failed: Google returned a response with code 429')
# - ['leash', 'least', 'lecture', 'length', 'lets'] -> TooManyRequestsError('The request failed: Google returned a response with code 429')
# - ['letter', 'levels', 'liberty', 'lifting', 'light'] -> TooManyRequestsError('The request failed: Google returned a response with code 429')
# - ['likely', 'limbs', 'lined', 'lines', 'lining'] -> TooManyRequestsError('The request failed: Google returned a response with code 429')
# - ['listens', 'lizards', 'loin', 'lots', 'luring'] -> TooManyRequestsError('The request failed: Google returned a response with code 429')
# - ['machine', 'machines', 'made', 'maiden', 'makeup'] -> TooManyRequestsError('The request failed: Google returned a response with code 429')
# - ['male', 'mammoths', 'mannered', 'manning', 'marches'] -> TooManyRequestsError('The request failed: Google returned a response with code 429')
# - ['marrying', 'massively', 'mat', 'mats', 'meal'] -> TooManyRequestsError('The request failed: Google returned a response with code 429')
# - ['medevil', 'members', 'messy', 'metal', 'meteorite'] -> TooManyRequestsError('The request failed: Google returned a response with code 429')
# - ['microphone', 'military', 'mind', 'mirrors', 'miserable'] -> TooManyRequestsError('The request failed: Google returned a response with code 429')
# - ['monsters', 'mood', 'moons', 'moses', 'mosquitoes'] -> TooManyRequestsError('The request failed: Google returned a response with code 429')
# - ['mother', 'mount', 'mountaintop', 'much', 'multiple'] -> TooManyRequestsError('The request failed: Google returned a response with code 429')
# - ['musical', 'mustache', 'myth', 'naked', 'name'] -> TooManyRequestsError('The request failed: Google returned a response with code 429')
# - ['named', 'navigating', 'nearly', 'nest', 'newspaper'] -> TooManyRequestsError('The request failed: Google returned a response with code 429')
# - ['nonchalant', 'nonchalantly', 'notepad', 'noticed', 'notices'] -> TooManyRequestsError('The request failed: Google returned a response with code 429')
# - ['numerous', 'object', 'oblivious', 'observe', 'occupied'] -> TooManyRequestsError('The request failed: Google returned a response with code 429')
# - ['odd', 'officials', 'opened', 'opens', 'operating'] -> TooManyRequestsError('The request failed: Google returned a response with code 429')
# - ['ordered', 'ottoman', 'outdoor', 'outer', 'outfits'] -> TooManyRequestsError('The request failed: Google returned a response with code 429')
# - ['outstretched', 'oven', 'oversized', 'pad', 'paddle'] -> TooManyRequestsError('The request failed: Google returned a response with code 429')
# - ['paddling', 'painted', 'pajamas', 'pans', 'pants'] -> TooManyRequestsError('The request failed: Google returned a response with code 429')
# - ['papers', 'parade', 'parchment', 'parents', 'parked'] -> TooManyRequestsError('The request failed: Google returned a response with code 429')
# - ['part', 'passing', 'past', 'pawing', 'peak'] -> TooManyRequestsError('The request failed: Google returned a response with code 429')
# - ['pedals', 'pendant', 'perplexed', 'pheasants', 'picnic'] -> TooManyRequestsError('The request failed: Google returned a response with code 429')
# - ['pictures', 'pie', 'pieces', 'pigeons', 'pile'] -> TooManyRequestsError('The request failed: Google returned a response with code 429')
# - ['piles', 'pillars', 'piloted', 'pine', 'pink'] -> TooManyRequestsError('The request failed: Google returned a response with code 429')
# - ['pinwheel', 'pitcher', 'piñata', 'placed', 'placing'] -> TooManyRequestsError('The request failed: Google returned a response with code 429')
# - ['plain', 'plant', 'plants', 'platform', 'player'] -> TooManyRequestsError('The request failed: Google returned a response with code 429')
# - ['players', 'playground', 'playpen', 'pocket', 'podium'] -> TooManyRequestsError('The request failed: Google returned a response with code 429')
# - ['point', 'polar', 'pole', 'poles', 'policewoman'] -> TooManyRequestsError('The request failed: Google returned a response with code 429')
# - ['position', 'positioned', 'pot', 'potion', 'pots'] -> TooManyRequestsError('The request failed: Google returned a response with code 429')
# - ['presence', 'present', 'presentation', 'presiding', 'press'] -> TooManyRequestsError('The request failed: Google returned a response with code 429')
# - ['previous', 'printed', 'prison', 'professional', 'property'] -> TooManyRequestsError('The request failed: Google returned a response with code 429')
# - ['propose', 'propped', 'psychiastrist', 'public', 'punishment'] -> TooManyRequestsError('The request failed: Google returned a response with code 429')
# - ['puppet', 'purchasing', 'pushed', 'put', 'puzzled'] -> TooManyRequestsError('The request failed: Google returned a response with code 429')
# - ['pyramid', 'quaint', 'questioning', 'questions', 'railroad'] -> TooManyRequestsError('The request failed: Google returned a response with code 429')
# - ['rain', 'rampaging', 'ranch', 'rancher', 'rate'] -> TooManyRequestsError('The request failed: Google returned a response with code 429')
# - ['rats', 'reach', 'reaches', 'reaching', 'reader'] -> TooManyRequestsError('The request failed: Google returned a response with code 429')
# - ['reads', 'receipt', 'recliner', 'recognize', 'recording'] -> TooManyRequestsError('The request failed: Google returned a response with code 429')
# - ['refrigerator', 'remains', 'remnants', 'rescue', 'resembling'] -> TooManyRequestsError('The request failed: Google returned a response with code 429')
# - ['reservation', 'rest', 'restrained', 'retail', 'reversed'] -> TooManyRequestsError('The request failed: Google returned a response with code 429')
# - ['reward', 'ribs', 'ride', 'rifle', 'ripped'] -> TooManyRequestsError('The request failed: Google returned a response with code 429')
# - ['rise', 'robes', 'rocket', 'rocking', 'rocks'] -> TooManyRequestsError('The request failed: Google returned a response with code 429')
# - ['rolled', 'roller', 'rolling', 'roped', 'round'] -> TooManyRequestsError('The request failed: Google returned a response with code 429')
# - ['sad', 'sailors', 'sand', 'sandwich', 'sandy'] -> TooManyRequestsError('The request failed: Google returned a response with code 429')
# - ['scared', 'scarves', 'scary', 'scratching', 'scroll'] -> TooManyRequestsError('The request failed: Google returned a response with code 429')
# - ['scythe', 'seat', 'seating', 'seeing', 'seemingly'] -> TooManyRequestsError('The request failed: Google returned a response with code 429')
# - ['sell', 'series', 'serpent', 'seven', 'sewing'] -> TooManyRequestsError('The request failed: Google returned a response with code 429')
# - ['shaken', 'shapes', 'sharply', 'shavings', 'sheet'] -> TooManyRequestsError('The request failed: Google returned a response with code 429')
# - ['shoot', 'short', 'shot', 'shoulder', 'shoveling'] -> TooManyRequestsError('The request failed: Google returned a response with code 429')
# - ['shows', 'signing', 'singing', 'six', 'skates'] -> TooManyRequestsError('The request failed: Google returned a response with code 429')
# - ['skinny', 'skins', 'skip', 'sleepwalking', 'slide'] -> ReadTimeout(ReadTimeoutError("HTTPSConnectionPool(host='trends.google.com', port=443): Read timed out. (read timeout=2)"))
# - ['slides', 'slightly', 'slop', 'sloping', 'slowly'] -> TooManyRequestsError('The request failed: Google returned a response with code 429')
# - ['smelly', 'smile', 'smoke', 'soaking', 'soda'] -> TooManyRequestsError('The request failed: Google returned a response with code 429')
# - ['spaceship', 'spear', 'spectator', 'speech', 'speed'] -> TooManyRequestsError('The request failed: Google returned a response with code 429')
# - ['sperm', 'spilling', 'spinning', 'spool', 'spraying'] -> TooManyRequestsError('The request failed: Google returned a response with code 429')
# - ['spread', 'spying', 'stadium', 'stage', 'stained'] -> TooManyRequestsError('The request failed: Google returned a response with code 429')
# - ['stanind', 'starring', 'stars', 'starting', 'startled'] -> TooManyRequestsError('The request failed: Google returned a response with code 429')
# - ['starving', 'state', 'statue', 'steering', 'step'] -> TooManyRequestsError('The request failed: Google returned a response with code 429')
# - ['stepping', 'stick', 'stockade', 'stones', 'stool'] -> TooManyRequestsError('The request failed: Google returned a response with code 429')
# - ['stools', 'stop', 'stopped', 'storm', 'straightjackets'] -> TooManyRequestsError('The request failed: Google returned a response with code 429')
# - ['stray', 'stretched', 'strewn', 'stroking', 'struggle'] -> TooManyRequestsError('The request failed: Google returned a response with code 429')
# - ['students', 'style', 'sub', 'sucking', 'suitcase'] -> TooManyRequestsError('The request failed: Google returned a response with code 429')
# - ['sulking', 'sunglasses', 'sunny', 'supermarket', 'supplies'] -> TooManyRequestsError('The request failed: Google returned a response with code 429')
# - ['support', 'surround', 'suspect', 'suspended', 'swallowing'] -> TooManyRequestsError('The request failed: Google returned a response with code 429')
# - ['sweatpants', 'swim', 'tablets', 'taken', 'talks'] -> TooManyRequestsError('The request failed: Google returned a response with code 429')
# - ['teeth', 'telephone', 'telling', 'tennis', 'tense'] -> TooManyRequestsError('The request failed: Google returned a response with code 429')
# - ['thick', 'thone', 'threatening', 'throwing', 'tier'] -> TooManyRequestsError('The request failed: Google returned a response with code 429')
# - ['times', 'toe', 'tone', 'topped', 'toppled'] -> TooManyRequestsError('The request failed: Google returned a response with code 429')
# - ['tossing', 'town', 'townhouses', 'track', 'trailing'] -> TooManyRequestsError('The request failed: Google returned a response with code 429')
# - ['trash', 'trophy', 'trough', 'turns', 'tuxedo'] -> TooManyRequestsError('The request failed: Google returned a response with code 429')
# - ['twice', 'underneath', 'unhappy', 'uphill', 'upside'] -> TooManyRequestsError('The request failed: Google returned a response with code 429')
# - ['video', 'vikings', 'waist', 'waiters', 'waitress'] -> TooManyRequestsError('The request failed: Google returned a response with code 429')
# - ['walls', 'wanting', 'wardrobe', 'washer', 'washers'] -> TooManyRequestsError('The request failed: Google returned a response with code 429')
# - ['washing', 'waterline', 'waterspout', 'wave', 'ways'] -> TooManyRequestsError('The request failed: Google returned a response with code 429')
# - ['waze', 'weirdly', 'went', 'whack', 'whal'] -> TooManyRequestsError('The request failed: Google returned a response with code 429')
# - ['width', 'wielding', 'wife', 'windmill', 'wings'] -> TooManyRequestsError('The request failed: Google returned a response with code 429')
# - ['winter', 'wise', 'wold', 'wood', 'woods'] -> TooManyRequestsError('The request failed: Google returned a response with code 429')
# - ['yeti', 'young', 'unusual', 'usually', 'time'] -> TooManyRequestsError('The request failed: Google returned a response with code 429')
# - ['exist', 'normally', 'wear', 'belong', 'typically'] -> TooManyRequestsError('The request failed: Google returned a response with code 429')
# - ['period', 'supposed', 'acting', 'could', 'impossible'] -> TooManyRequestsError('The request failed: Google returned a response with code 429')
# - ['real', 'use', 'color', 'dangerous', 'fit'] -> TooManyRequestsError('The request failed: Google returned a response with code 429')
# - ['fly', 'found', 'gigantic', 'rather', 'upright'] -> TooManyRequestsError('The request failed: Google returned a response with code 429')
# - ['able', 'additionally', 'anyone', 'bears', 'element'] -> TooManyRequestsError('The request failed: Google returned a response with code 429')
# - ['expect', 'eyes', 'intelligent', 'longer', 'meant'] -> TooManyRequestsError('The request failed: Google returned a response with code 429')
# - ['done', 'eggs', 'either', 'experiments', 'fine'] -> ConnectionError(MaxRetryError('HTTPSConnectionPool(host=\'trends.google.com\', port=443): Max retries exceeded with url: /trends/api/explore?hl=en-US&tz=360&req=%7B%22comparisonItem%22%3A+%5B%7B%22keyword%22%3A+%22done%22%2C+%22time%22%3A+%222016-03-01+2023-09-30%22%2C+%22geo%22%3A+%22US%22%7D%2C+%7B%22keyword%22%3A+%22eggs%22%2C+%22time%22%3A+%222016-03-01+2023-09-30%22%2C+%22geo%22%3A+%22US%22%7D%2C+%7B%22keyword%22%3A+%22either%22%2C+%22time%22%3A+%222016-03-01+2023-09-30%22%2C+%22geo%22%3A+%22US%22%7D%2C+%7B%22keyword%22%3A+%22experiments%22%2C+%22time%22%3A+%222016-03-01+2023-09-30%22%2C+%22geo%22%3A+%22US%22%7D%2C+%7B%22keyword%22%3A+%22fine%22%2C+%22time%22%3A+%222016-03-01+2023-09-30%22%2C+%22geo%22%3A+%22US%22%7D%5D%2C+%22category%22%3A+0%2C+%22property%22%3A+%22%22%7D (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x35a272db0>: Failed to resolve \'trends.google.com\' ([Errno 8] nodename nor servname provided, or not known)"))'))
# - ['lounge', 'mazes', 'meetings', 'needs', 'objects'] -> ConnectionError(MaxRetryError('HTTPSConnectionPool(host=\'trends.google.com\', port=443): Max retries exceeded with url: /trends/api/explore?hl=en-US&tz=360&req=%7B%22comparisonItem%22%3A+%5B%7B%22keyword%22%3A+%22lounge%22%2C+%22time%22%3A+%222016-03-01+2023-09-30%22%2C+%22geo%22%3A+%22US%22%7D%2C+%7B%22keyword%22%3A+%22mazes%22%2C+%22time%22%3A+%222016-03-01+2023-09-30%22%2C+%22geo%22%3A+%22US%22%7D%2C+%7B%22keyword%22%3A+%22meetings%22%2C+%22time%22%3A+%222016-03-01+2023-09-30%22%2C+%22geo%22%3A+%22US%22%7D%2C+%7B%22keyword%22%3A+%22needs%22%2C+%22time%22%3A+%222016-03-01+2023-09-30%22%2C+%22geo%22%3A+%22US%22%7D%2C+%7B%22keyword%22%3A+%22objects%22%2C+%22time%22%3A+%222016-03-01+2023-09-30%22%2C+%22geo%22%3A+%22US%22%7D%5D%2C+%22category%22%3A+0%2C+%22property%22%3A+%22%22%7D (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x35d21e960>: Failed to resolve \'trends.google.com\' ([Errno 8] nodename nor servname provided, or not known)"))'))
# ...
# - ['hunt', 'illegal', 'improbable', 'include', 'incredibly'] -> ConnectionError(MaxRetryError('HTTPSConnectionPool(host=\'trends.google.com\', port=443): Max retries exceeded with url: /trends/api/explore?hl=en-US&tz=360&req=%7B%22comparisonItem%22%3A+%5B%7B%22keyword%22%3A+%22hunt%22%2C+%22time%22%3A+%222016-03-01+2023-09-30%22%2C+%22geo%22%3A+%22US%22%7D%2C+%7B%22keyword%22%3A+%22illegal%22%2C+%22time%22%3A+%222016-03-01+2023-09-30%22%2C+%22geo%22%3A+%22US%22%7D%2C+%7B%22keyword%22%3A+%22improbable%22%2C+%22time%22%3A+%222016-03-01+2023-09-30%22%2C+%22geo%22%3A+%22US%22%7D%2C+%7B%22keyword%22%3A+%22include%22%2C+%22time%22%3A+%222016-03-01+2023-09-30%22%2C+%22geo%22%3A+%22US%22%7D%2C+%7B%22keyword%22%3A+%22incredibly%22%2C+%22time%22%3A+%222016-03-01+2023-09-30%22%2C+%22geo%22%3A+%22US%22%7D%5D%2C+%22category%22%3A+0%2C+%22property%22%3A+%22%22%7D (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x35d223710>: Failed to resolve \'trends.google.com\' ([Errno 8] nodename nor servname provided, or not known)"))'))
# - ['indicates', 'industrial', 'ineffective', 'informally', 'injuries'] -> ConnectionError(MaxRetryError('HTTPSConnectionPool(host=\'trends.google.com\', port=443): Max retries exceeded with url: /trends/api/explore?hl=en-US&tz=360&req=%7B%22comparisonItem%22%3A+%5B%7B%22keyword%22%3A+%22indicates%22%2C+%22time%22%3A+%222016-03-01+2023-09-30%22%2C+%22geo%22%3A+%22US%22%7D%2C+%7B%22keyword%22%3A+%22industrial%22%2C+%22time%22%3A+%222016-03-01+2023-09-30%22%2C+%22geo%22%3A+%22US%22%7D%2C+%7B%22keyword%22%3A+%22ineffective%22%2C+%22time%22%3A+%222016-03-01+2023-09-30%22%2C+%22geo%22%3A+%22US%22%7D%2C+%7B%22keyword%22%3A+%22informally%22%2C+%22time%22%3A+%222016-03-01+2023-09-30%22%2C+%22geo%22%3A+%22US%22%7D%2C+%7B%22keyword%22%3A+%22injuries%22%2C+%22time%22%3A+%222016-03-01+2023-09-30%22%2C+%22geo%22%3A+%22US%22%7D%5D%2C+%22category%22%3A+0%2C+%22property%22%3A+%22%22%7D (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x166531520>: Failed to resolve \'trends.google.com\' ([Errno 8] nodename nor servname provided, or not known)"))'))
# - ['injury', 'instant', 'intense', 'interest', 'interesting'] -> ConnectionError(MaxRetryError('HTTPSConnectionPool(host=\'trends.google.com\', port=443): Max retries exceeded with url: /trends/api/explore?hl=en-US&tz=360&req=%7B%22comparisonItem%22%3A+%5B%7B%22keyword%22%3A+%22injury%22%2C+%22time%22%3A+%222016-03-01+2023-09-30%22%2C+%22geo%22%3A+%22US%22%7D%2C+%7B%22keyword%22%3A+%22instant%22%2C+%22time%22%3A+%222016-03-01+2023-09-30%22%2C+%22geo%22%3A+%22US%22%7D%2C+%7B%22keyword%22%3A+%22intense%22%2C+%22time%22%3A+%222016-03-01+2023-09-30%22%2C+%22geo%22%3A+%22US%22%7D%2C+%7B%22keyword%22%3A+%22interest%22%2C+%22time%22%3A+%222016-03-01+2023-09-30%22%2C+%22geo%22%3A+%22US%22%7D%2C+%7B%22keyword%22%3A+%22interesting%22%2C+%22time%22%3A+%222016-03-01+2023-09-30%22%2C+%22geo%22%3A+%22US%22%7D%5D%2C+%22category%22%3A+0%2C+%22property%22%3A+%22%22%7D (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x35d223830>: Failed to resolve \'trends.google.com\' ([Errno 8] nodename nor servname provided, or not known)"))'))
# - ['intravenous', 'invisible', 'involve', 'islands', 'jumpsuits'] -> ConnectionError(MaxRetryError('HTTPSConnectionPool(host=\'trends.google.com\', port=443): Max retries exceeded with url: /trends/api/explore?hl=en-US&tz=360&req=%7B%22comparisonItem%22%3A+%5B%7B%22keyword%22%3A+%22intravenous%22%2C+%22time%22%3A+%222016-03-01+2023-09-30%22%2C+%22geo%22%3A+%22US%22%7D%2C+%7B%22keyword%22%3A+%22invisible%22%2C+%22time%22%3A+%222016-03-01+2023-09-30%22%2C+%22geo%22%3A+%22US%22%7D%2C+%7B%22keyword%22%3A+%22involve%22%2C+%22time%22%3A+%222016-03-01+2023-09-30%22%2C+%22geo%22%3A+%22US%22%7D%2C+%7B%22keyword%22%3A+%22islands%22%2C+%22time%22%3A+%222016-03-01+2023-09-30%22%2C+%22geo%22%3A+%22US%22%7D%2C+%7B%22keyword%22%3A+%22jumpsuits%22%2C+%22time%22%3A+%222016-03-01+2023-09-30%22%2C+%22geo%22%3A+%22US%22%7D%5D%2C+%22category%22%3A+0%2C+%22property%22%3A+%22%22%7D (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x1665314c0>: Failed to resolve \'trends.google.com\' ([Errno 8] nodename nor servname provided, or not known)"))'))
# - ['jungles', 'keeling', 'keep', 'kill', 'killed'] -> ConnectionError(MaxRetryError('HTTPSConnectionPool(host=\'trends.google.com\', port=443): Max retries exceeded with url: /trends/api/explore?hl=en-US&tz=360&req=%7B%22comparisonItem%22%3A+%5B%7B%22keyword%22%3A+%22jungles%22%2C+%22time%22%3A+%222016-03-01+2023-09-30%22%2C+%22geo%22%3A+%22US%22%7D%2C+%7B%22keyword%22%3A+%22keeling%22%2C+%22time%22%3A+%222016-03-01+2023-09-30%22%2C+%22geo%22%3A+%22US%22%7D%2C+%7B%22keyword%22%3A+%22keep%22%2C+%22time%22%3A+%222016-03-01+2023-09-30%22%2C+%22geo%22%3A+%22US%22%7D%2C+%7B%22keyword%22%3A+%22kill%22%2C+%22time%22%3A+%222016-03-01+2023-09-30%22%2C+%22geo%22%3A+%22US%22%7D%2C+%7B%22keyword%22%3A+%22killed%22%2C+%22time%22%3A+%222016-03-01+2023-09-30%22%2C+%22geo%22%3A+%22US%22%7D%5D%2C+%22category%22%3A+0%2C+%22property%22%3A+%22%22%7D (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x166531dc0>: Failed to resolve \'trends.google.com\' ([Errno 8] nodename nor servname provided, or not known)"))'))
# - ['killing', 'kitchens', 'kneading', 'knives', 'lamps'] -> ConnectionError(MaxRetryError('HTTPSConnectionPool(host=\'trends.google.com\', port=443): Max retries exceeded with url: /trends/api/explore?hl=en-US&tz=360&req=%7B%22comparisonItem%22%3A+%5B%7B%22keyword%22%3A+%22killing%22%2C+%22time%22%3A+%222016-03-01+2023-09-30%22%2C+%22geo%22%3A+%22US%22%7D%2C+%7B%22keyword%22%3A+%22kitchens%22%2C+%22time%22%3A+%222016-03-01+2023-09-30%22%2C+%22geo%22%3A+%22US%22%7D%2C+%7B%22keyword%22%3A+%22kneading%22%2C+%22time%22%3A+%222016-03-01+2023-09-30%22%2C+%22geo%22%3A+%22US%22%7D%2C+%7B%22keyword%22%3A+%22knives%22%2C+%22time%22%3A+%222016-03-01+2023-09-30%22%2C+%22geo%22%3A+%22US%22%7D%2C+%7B%22keyword%22%3A+%22lamps%22%2C+%22time%22%3A+%222016-03-01+2023-09-30%22%2C+%22geo%22%3A+%22US%22%7D%5D%2C+%22category%22%3A+0%2C+%22property%22%3A+%22%22%7D (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x35d21f230>: Failed to resolve \'trends.google.com\' ([Errno 8] nodename nor servname provided, or not known)"))'))
# - ['land', 'lay', 'learned', 'ledges', 'legal'] -> ConnectionError(MaxRetryError('HTTPSConnectionPool(host=\'trends.google.com\', port=443): Max retries exceeded with url: /trends/api/explore?hl=en-US&tz=360&req=%7B%22comparisonItem%22%3A+%5B%7B%22keyword%22%3A+%22land%22%2C+%22time%22%3A+%222016-03-01+2023-09-30%22%2C+%22geo%22%3A+%22US%22%7D%2C+%7B%22keyword%22%3A+%22lay%22%2C+%22time%22%3A+%222016-03-01+2023-09-30%22%2C+%22geo%22%3A+%22US%22%7D%2C+%7B%22keyword%22%3A+%22learned%22%2C+%22time%22%3A+%222016-03-01+2023-09-30%22%2C+%22geo%22%3A+%22US%22%7D%2C+%7B%22keyword%22%3A+%22ledges%22%2C+%22time%22%3A+%222016-03-01+2023-09-30%22%2C+%22geo%22%3A+%22US%22%7D%2C+%7B%22keyword%22%3A+%22legal%22%2C+%22time%22%3A+%222016-03-01+2023-09-30%22%2C+%22geo%22%3A+%22US%22%7D%5D%2C+%22category%22%3A+0%2C+%22property%22%3A+%22%22%7D (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x35d21cc20>: Failed to resolve \'trends.google.com\' ([Errno 8] nodename nor servname provided, or not known)"))'))
# - ['legend', 'level', 'lift', 'likes', 'lives'] -> ConnectionError(MaxRetryError('HTTPSConnectionPool(host=\'trends.google.com\', port=443): Max retries exceeded with url: /trends/api/explore?hl=en-US&tz=360&req=%7B%22comparisonItem%22%3A+%5B%7B%22keyword%22%3A+%22legend%22%2C+%22time%22%3A+%222016-03-01+2023-09-30%22%2C+%22geo%22%3A+%22US%22%7D%2C+%7B%22keyword%22%3A+%22level%22%2C+%22time%22%3A+%222016-03-01+2023-09-30%22%2C+%22geo%22%3A+%22US%22%7D%2C+%7B%22keyword%22%3A+%22lift%22%2C+%22time%22%3A+%222016-03-01+2023-09-30%22%2C+%22geo%22%3A+%22US%22%7D%2C+%7B%22keyword%22%3A+%22likes%22%2C+%22time%22%3A+%222016-03-01+2023-09-30%22%2C+%22geo%22%3A+%22US%22%7D%2C+%7B%22keyword%22%3A+%22lives%22%2C+%22time%22%3A+%222016-03-01+2023-09-30%22%2C+%22geo%22%3A+%22US%22%7D%5D%2C+%22category%22%3A+0%2C+%22property%22%3A+%22%22%7D (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x166532450>: Failed to resolve \'trends.google.com\' ([Errno 8] nodename nor servname provided, or not known)"))'))
# - ['lobster', 'location', 'lock', 'longing', 'mammoth'] -> ConnectionError(MaxRetryError('HTTPSConnectionPool(host=\'trends.google.com\', port=443): Max retries exceeded with url: /trends/api/explore?hl=en-US&tz=360&req=%7B%22comparisonItem%22%3A+%5B%7B%22keyword%22%3A+%22lobster%22%2C+%22time%22%3A+%222016-03-01+2023-09-30%22%2C+%22geo%22%3A+%22US%22%7D%2C+%7B%22keyword%22%3A+%22location%22%2C+%22time%22%3A+%222016-03-01+2023-09-30%22%2C+%22geo%22%3A+%22US%22%7D%2C+%7B%22keyword%22%3A+%22lock%22%2C+%22time%22%3A+%222016-03-01+2023-09-30%22%2C+%22geo%22%3A+%22US%22%7D%2C+%7B%22keyword%22%3A+%22longing%22%2C+%22time%22%3A+%222016-03-01+2023-09-30%22%2C+%22geo%22%3A+%22US%22%7D%2C+%7B%22keyword%22%3A+%22mammoth%22%2C+%22time%22%3A+%222016-03-01+2023-09-30%22%2C+%22geo%22%3A+%22US%22%7D%5D%2C+%22category%22%3A+0%2C+%22property%22%3A+%22%22%7D (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x1665304a0>: Failed to resolve \'trends.google.com\' ([Errno 8] nodename nor servname provided, or not known)"))'))
# - ['managed', 'massive', 'may', 'mean', 'meat'] -> ConnectionError(MaxRetryError('HTTPSConnectionPool(host=\'trends.google.com\', port=443): Max retries exceeded with url: /trends/api/explore?hl=en-US&tz=360&req=%7B%22comparisonItem%22%3A+%5B%7B%22keyword%22%3A+%22managed%22%2C+%22time%22%3A+%222016-03-01+2023-09-30%22%2C+%22geo%22%3A+%22US%22%7D%2C+%7B%22keyword%22%3A+%22massive%22%2C+%22time%22%3A+%222016-03-01+2023-09-30%22%2C+%22geo%22%3A+%22US%22%7D%2C+%7B%22keyword%22%3A+%22may%22%2C+%22time%22%3A+%222016-03-01+2023-09-30%22%2C+%22geo%22%3A+%22US%22%7D%2C+%7B%22keyword%22%3A+%22mean%22%2C+%22time%22%3A+%222016-03-01+2023-09-30%22%2C+%22geo%22%3A+%22US%22%7D%2C+%7B%22keyword%22%3A+%22meat%22%2C+%22time%22%3A+%222016-03-01+2023-09-30%22%2C+%22geo%22%3A+%22US%22%7D%5D%2C+%22category%22%3A+0%2C+%22property%22%3A+%22%22%7D (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x35d21edb0>: Failed to resolve \'trends.google.com\' ([Errno 8] nodename nor servname provided, or not known)"))'))
# - ['melt', 'might', 'mirroring', 'missing', 'mouths'] -> TooManyRequestsError('The request failed: Google returned a response with code 429')
# - ['moving', 'mundane', 'musicians', 'native', 'naturally'] -> TooManyRequestsError('The request failed: Google returned a response with code 429')
# - ['needing', 'neighbor', 'nested', 'nesting', 'never'] -> TooManyRequestsError('The request failed: Google returned a response with code 429')
# - ['operate', 'opposable', 'orbiting', 'organs', 'outline'] -> TooManyRequestsError('The request failed: Google returned a response with code 429')
# - ['overkill', 'oxygen', 'packed', 'pain', 'panic'] -> ConnectionError(MaxRetryError('HTTPSConnectionPool(host=\'trends.google.com\', port=443): Max retries exceeded with url: /trends/api/explore?hl=en-US&tz=360&req=%7B%22comparisonItem%22%3A+%5B%7B%22keyword%22%3A+%22overkill%22%2C+%22time%22%3A+%222016-03-01+2023-09-30%22%2C+%22geo%22%3A+%22US%22%7D%2C+%7B%22keyword%22%3A+%22oxygen%22%2C+%22time%22%3A+%222016-03-01+2023-09-30%22%2C+%22geo%22%3A+%22US%22%7D%2C+%7B%22keyword%22%3A+%22packed%22%2C+%22time%22%3A+%222016-03-01+2023-09-30%22%2C+%22geo%22%3A+%22US%22%7D%2C+%7B%22keyword%22%3A+%22pain%22%2C+%22time%22%3A+%222016-03-01+2023-09-30%22%2C+%22geo%22%3A+%22US%22%7D%2C+%7B%22keyword%22%3A+%22panic%22%2C+%22time%22%3A+%222016-03-01+2023-09-30%22%2C+%22geo%22%3A+%22US%22%7D%5D%2C+%22category%22%3A+0%2C+%22property%22%3A+%22%22%7D (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x166532570>: Failed to resolve \'trends.google.com\' ([Errno 8] nodename nor servname provided, or not known)"))'))
# - ['parading', 'particular', 'parts', 'peacefully', 'peculiar'] -> ConnectionError(MaxRetryError('HTTPSConnectionPool(host=\'trends.google.com\', port=443): Max retries exceeded with url: /trends/api/explore?hl=en-US&tz=360&req=%7B%22comparisonItem%22%3A+%5B%7B%22keyword%22%3A+%22parading%22%2C+%22time%22%3A+%222016-03-01+2023-09-30%22%2C+%22geo%22%3A+%22US%22%7D%2C+%7B%22keyword%22%3A+%22particular%22%2C+%22time%22%3A+%222016-03-01+2023-09-30%22%2C+%22geo%22%3A+%22US%22%7D%2C+%7B%22keyword%22%3A+%22parts%22%2C+%22time%22%3A+%222016-03-01+2023-09-30%22%2C+%22geo%22%3A+%22US%22%7D%2C+%7B%22keyword%22%3A+%22peacefully%22%2C+%22time%22%3A+%222016-03-01+2023-09-30%22%2C+%22geo%22%3A+%22US%22%7D%2C+%7B%22keyword%22%3A+%22peculiar%22%2C+%22time%22%3A+%222016-03-01+2023-09-30%22%2C+%22geo%22%3A+%22US%22%7D%5D%2C+%22category%22%3A+0%2C+%22property%22%3A+%22%22%7D (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x166530c80>: Failed to resolve \'trends.google.com\' ([Errno 8] nodename nor servname provided, or not known)"))'))
# - ['peeping', 'peg', 'per', 'perfect', 'periods'] -> ConnectionError(MaxRetryError('HTTPSConnectionPool(host=\'trends.google.com\', port=443): Max retries exceeded with url: /trends/api/explore?hl=en-US&tz=360&req=%7B%22comparisonItem%22%3A+%5B%7B%22keyword%22%3A+%22peeping%22%2C+%22time%22%3A+%222016-03-01+2023-09-30%22%2C+%22geo%22%3A+%22US%22%7D%2C+%7B%22keyword%22%3A+%22peg%22%2C+%22time%22%3A+%222016-03-01+2023-09-30%22%2C+%22geo%22%3A+%22US%22%7D%2C+%7B%22keyword%22%3A+%22per%22%2C+%22time%22%3A+%222016-03-01+2023-09-30%22%2C+%22geo%22%3A+%22US%22%7D%2C+%7B%22keyword%22%3A+%22perfect%22%2C+%22time%22%3A+%222016-03-01+2023-09-30%22%2C+%22geo%22%3A+%22US%22%7D%2C+%7B%22keyword%22%3A+%22periods%22%2C+%22time%22%3A+%222016-03-01+2023-09-30%22%2C+%22geo%22%3A+%22US%22%7D%5D%2C+%22category%22%3A+0%2C+%22property%22%3A+%22%22%7D (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x35d21a240>: Failed to resolve \'trends.google.com\' ([Errno 8] nodename nor servname provided, or not known)"))'))
# - ['pets', 'physically', 'pinyata', 'pipe', 'placement'] -> ConnectionError(MaxRetryError('HTTPSConnectionPool(host=\'trends.google.com\', port=443): Max retries exceeded with url: /trends/api/explore?hl=en-US&tz=360&req=%7B%22comparisonItem%22%3A+%5B%7B%22keyword%22%3A+%22pets%22%2C+%22time%22%3A+%222016-03-01+2023-09-30%22%2C+%22geo%22%3A+%22US%22%7D%2C+%7B%22keyword%22%3A+%22physically%22%2C+%22time%22%3A+%222016-03-01+2023-09-30%22%2C+%22geo%22%3A+%22US%22%7D%2C+%7B%22keyword%22%3A+%22pinyata%22%2C+%22time%22%3A+%222016-03-01+2023-09-30%22%2C+%22geo%22%3A+%22US%22%7D%2C+%7B%22keyword%22%3A+%22pipe%22%2C+%22time%22%3A+%222016-03-01+2023-09-30%22%2C+%22geo%22%3A+%22US%22%7D%2C+%7B%22keyword%22%3A+%22placement%22%2C+%22time%22%3A+%222016-03-01+2023-09-30%22%2C+%22geo%22%3A+%22US%22%7D%5D%2C+%22category%22%3A+0%2C+%22property%22%3A+%22%22%7D (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x166533920>: Failed to resolve \'trends.google.com\' ([Errno 8] nodename nor servname provided, or not known)"))'))
# - ['royal', 'tailor', 'workplace', 'age', 'antique'] -> TooManyRequestsError('The request failed: Google returned a response with code 429')
#             soldiers  somewhat  son  sort  sorting
# date
# 2016-03-01         9         0   91     7        2
# 2016-04-01         9         0   89     7        2
# 2016-05-01        11         0   90     6        2
# 2016-06-01         8         0   90     6        2
# 2016-07-01         7         0   89     5        2

# %%
# --- Config ---
INPUT_WIDE_CSV = Path("data/GoogleTrends/google_trends_ALL_tokens_2016_03_to_2023_09_US.csv")  # adjust if needed
OUTPUT_MEANS_CSV = Path("data/GoogleTrends/google_trends_means_2016_03_to_2023_09_US.csv")

# Use existing trends_wide if present; else load from CSV
if "trends_wide" in globals():
    df = trends_wide.copy()
else:
    # First column is the date index in the saved file
    df = pd.read_csv(INPUT_WIDE_CSV, index_col=0, parse_dates=True)

# Keep only numeric columns (keywords)
num = df.select_dtypes(include="number")

# Compute mean interest per keyword across the full timeframe
means = num.mean(axis=0, skipna=True)

# In case of any accidental duplicate column names, average them
means = means.groupby(level=0).mean()

# Build tidy result and sort
out = (
    means.reset_index()
         .rename(columns={"index": "token", 0: "mean_interest"})
         .sort_values("mean_interest", ascending=False)
         .reset_index(drop=True)
)

out["mean_interest"] = out["mean_interest"].round(3)

# Save
OUTPUT_MEANS_CSV.parent.mkdir(parents=True, exist_ok=True)
out.to_csv(OUTPUT_MEANS_CSV, index=False)

# %% [markdown]
# ### Analysis of google trends data vs our data

# %% [markdown]
# Why do we talk more about men than women in captions ?

# %%
FREQ_FILES = [
    "data/GoogleTrends/frequent_words/image_descriptions__unigrams_nltk.csv",
    "data/GoogleTrends/frequent_words/image_locations__unigrams_nltk.csv",
    "data/GoogleTrends/frequent_words/image_uncanny_descriptions__unigrams_nltk.csv",
    "data/GoogleTrends/frequent_words/questions__unigrams_nltk.csv",
]


TRENDS_WIDE = "data/GoogleTrends/google_trends_ALL_tokens_2016_03_to_2023_09_US.csv"
TRENDS_MEANS = "data/GoogleTrends/google_trends_means_2016_03_to_2023_09_US.csv"

# focus groups
FOCUS_GROUPS = {
    "man": ["man", "men"],
    "woman": ["woman", "women"],
}

def load_frequencies(freq_files):
    """Load multiple unigram CSVs and sum counts across files """
    frames = []
    for f in freq_files:
        df = pd.read_csv(f)
        if "token" not in df.columns or "count" not in df.columns:
            raise ValueError(f"{f} must have columns: token,count")
        frames.append(df[["token", "count"]].copy())
    big = pd.concat(frames, ignore_index=True)
    big["token"] = big["token"].astype(str)
    agg = big.groupby("token", as_index=False)["count"].sum().sort_values("count", ascending=False)
    return agg

def group_count(freq_df, words):
    """Sum counts for a list of words (focus_groups)."""
    words = [w.lower() for w in words]
    sub = freq_df[freq_df["token"].str.lower().isin(words)]
    return int(sub["count"].sum())

def best_trends_token(trends_df, candidates):
    """ picks the first word from the group that actually exists in the Trends data."""
    for t in candidates:
        if t in trends_df.columns:
            return t
    return None

def zscore_df(df):
    """Z-score columns independently (drop all-NaN columns)."""
    df = df.copy()
    df = df.dropna(axis=1, how="all")
    scaler = StandardScaler(with_mean=True, with_std=True)
    arr = scaler.fit_transform(df.fillna(0.0))
    return pd.DataFrame(arr, index=df.index, columns=df.columns)


freq = load_frequencies(FREQ_FILES)
print(f"Loaded {len(freq)} unique tokens from your dataset.")

trends_wide = pd.read_csv(TRENDS_WIDE, index_col=0, parse_dates=True)
print(f"Trends shape (time x tokens): {trends_wide.shape}")

# Means per token. Otherwise compute from wide:
try:
    trends_means = pd.read_csv(TRENDS_MEANS)
    if not {"token", "mean_interest"}.issubset(trends_means.columns):
        raise ValueError("means file missing required columns")
    trends_means = trends_means[["token", "mean_interest"]].copy()
except Exception:
    # compute if not present
    cols_numeric = trends_wide.select_dtypes(include="number").columns
    trends_means = (
        trends_wide[cols_numeric]
        .mean(axis=0)
        .rename("mean_interest")
        .reset_index()
        .rename(columns={"index": "token"})
    )


print("\n=== Focus groups: dataset counts and ratios ===")
group_counts = {}
for group_name, variants in FOCUS_GROUPS.items():
    c = group_count(freq, variants)
    group_counts[group_name] = c
    print(f"- {group_name}: {c} (tokens: {variants})")

# compute ratio A/B
if len(group_counts) == 2:
    k = list(group_counts.keys())
    a, b = k[0], k[1]
    ra = group_counts[a]
    rb = group_counts[b]
    ratio = (ra / rb) if rb else np.nan
    print(f"Ratio {a}/{b}: {ratio:.2f}")

# Choose one representative token per group that actually exists in trends_wide
rep_tokens = {}
for g, variants in FOCUS_GROUPS.items():
    tok = best_trends_token(trends_wide, variants)
    if tok is not None:
        rep_tokens[g] = tok

if rep_tokens:
    print("\nRepresentative tokens found in Trends:", rep_tokens)
    ax = trends_wide[list(rep_tokens.values())].plot(figsize=(10,4), title="Google Trends: focus groups over time")
    ax.set_xlabel("Date")
    ax.set_ylabel("Interest (0-100)")
    plt.show()
else:
    print("\nNo representative tokens from your focus groups were found in the Trends table.")


# Merge per-token dataset counts with mean Trends interest
merged = freq.merge(trends_means, on="token", how="inner")
merged = merged[merged["mean_interest"].notna()].copy()

# Overall correlations across ALL tokens 
if len(merged) >= 3:
    pear = pearsonr(merged["count"], merged["mean_interest"])[0]
    spear = spearmanr(merged["count"], merged["mean_interest"]).correlation
    print(f"\nCorrelation (ALL TOKENS): Pearson={pear:.3f}, Spearman={spear:.3f}")
else:
    print("\nNot enough tokens overlap between dataset and Trends to compute overall correlation.")

# Scatter plot (log-scale counts to avoid domination by extreme words)
if len(merged) >= 3:
    plt.figure(figsize=(6,5))
    plt.scatter(merged["mean_interest"], np.log1p(merged["count"]), s=12)
    plt.xlabel("Google Trends mean interest")
    plt.ylabel("log(1 + dataset count)")
    plt.title("Dataset frequency vs. Google Trends popularity")
    plt.grid(True, alpha=0.3)
    plt.show()


# If you have exactly 2 groups, check whether ordering agrees: dataset vs trends
if len(FOCUS_GROUPS) == 2 and rep_tokens:
    # dataset ordering
    k = list(FOCUS_GROUPS.keys())
    a, b = k[0], k[1]
    count_a = group_counts.get(a, 0)
    count_b = group_counts.get(b, 0)
    ds_order = np.sign(count_a - count_b)  # +1 if a>b, -1 if a<b, 0 if tie

    # trends ordering using MEAN interest of representative tokens 
    ta = rep_tokens.get(a, None)
    tb = rep_tokens.get(b, None)
    if ta and tb:
        trend_a = trends_wide[ta].mean()
        trend_b = trends_wide[tb].mean()
        tr_order = np.sign(trend_a - trend_b)
        print(f"\nOrdering check (dataset vs. Trends):")
        print(f"- Dataset: {a}={count_a} vs {b}={count_b}  => {'a>b' if ds_order>0 else 'a<b' if ds_order<0 else 'tie'}")
        print(f"- Trends : {a}={trend_a:.2f} vs {b}={trend_b:.2f} => {'a>b' if tr_order>0 else 'a<b' if tr_order<0 else 'tie'}")
    else:
        print("\nCannot compute ordering: representative tokens missing in Trends.")


# correlation between the two time series
if len(rep_tokens) >= 2:
    sub = trends_wide[list(rep_tokens.values())].copy()
    sub_z = zscore_df(sub)   # normalize each series
    if sub_z.shape[1] == 2:
        a_col, b_col = sub_z.columns.tolist()
        pair = sub_z[[a_col, b_col]].dropna()
        tau = kendalltau(pair[a_col], pair[b_col]).correlation
        pear_t = pearsonr(pair[a_col], pair[b_col])[0]
        print(f"\nTime-shape agreement (z-scored): Pearson={pear_t:.3f}, Kendall tau={tau:.3f}")
        pair.plot(figsize=(10,4), title=f"Z-scored Trends: {a_col} vs {b_col}")
        plt.xlabel("Date"); plt.ylabel("z-score"); plt.show()
# Out:
# Loaded 2263 unique tokens from your dataset.
# Trends shape (time x tokens): (91, 508)
#
# === Focus groups: dataset counts and ratios ===
# - man: 558 (tokens: ['man', 'men'])
# - woman: 158 (tokens: ['woman', 'women'])
# Ratio man/woman: 3.53
#
# No representative tokens from your focus groups were found in the Trends table.
#
# Correlation (ALL TOKENS): Pearson=0.102, Spearman=0.099

# %% [markdown]
# The pearson correlation is 0.094 which is very close to 0. This mean that there is no strong linear link between dataset frequency and Google Trends interest.
# The pearman correlation is 0.174 which means a weak positive tendency. Some of the words that appear more often in the dataset are slightly more popular on Google, but not consistently.
# This indicates that the vocabulary used in our dataset does not strongly reflect general public interest.
# The dataset therefore captures a specific linguistic or cultural focus, rather than mirroring general online attention.
#
# The scatter plot shows no strong linear pattern between dataset frequency and Google Trends popularity.
# Words that are frequent in our corpus are not consistently popular in Google searches.

# %% [markdown]
# Are negative words more frequent during years with global crises like pandemic?
# Frenquecy of negative and pandemic words during years.

# %%
trends = pd.read_csv("data/GoogleTrends/google_trends_ALL_tokens_2016_03_to_2023_09_US.csv", index_col=0, parse_dates=True)

NEGATIVE_WORDS = ["fear", "death", "anxiety", "sad", "worry", "crisis", "anger", "pain", "stress", "hate", "war", "depression", "trauma", "suffering", "loss", "grief", "panic", "nervous", "frustration", "helplessness"]
PANDEMIC_WORDS = ["pandemic", "virus", "covid", "quarantine", "lockdown", "vaccine", "mask", "social", "isolation", "outbreak", "immunity", "testing", "symptoms", "healthcare", "hygiene", "sanitizer", "ventilator", "distance","immunity"]

neg_available = [w for w in NEGATIVE_WORDS if w in trends.columns]
pand_available = [w for w in PANDEMIC_WORDS if w in trends.columns]

print("Negative words found:", neg_available)
print("Pandemic words found:", pand_available)

# average interest for each group over time
group_series = pd.DataFrame(index=trends.index)
group_series["negative_mean"] = trends[neg_available].mean(axis=1)
group_series["pandemic_mean"] = trends[pand_available].mean(axis=1)

# Optional: z-score normalize to highlight relative changes
scaler = StandardScaler()
group_series_z = pd.DataFrame(scaler.fit_transform(group_series), columns=group_series.columns, index=group_series.index)

# Plot raw and normalized series
fig, ax = plt.subplots(2, 1, figsize=(10, 7), sharex=True)

# (1) Raw means
group_series.plot(ax=ax[0], title="Google Trends: Type of words over time", linewidth=2)
ax[0].set_ylabel("Interest (0–100)")
ax[0].legend(["Negative words", "Pandemic words"])
ax[0].axvspan("2020-03", "2021-12", color="red", alpha=0.15, label="Pandemic period")

# (2) Z-scored (to compare shapes)
group_series_z.plot(ax=ax[1], linewidth=2)
ax[1].set_ylabel("Z-score (normalized)")
ax[1].axvspan("2020-03", "2021-12", color="red", alpha=0.15)
ax[1].set_xlabel("Date")

plt.tight_layout()
plt.show()

# Quantitative summary: compare mean interest before/during/after pandemic
pre_covid = group_series.loc["2016-03":"2020-02"].mean()
covid = group_series.loc["2020-03":"2021-12"].mean()
post_covid = group_series.loc["2022-01":"2023-09"].mean()

summary = pd.DataFrame({"pre_covid": pre_covid, "covid": covid, "post_covid": post_covid})
print("\nAverage interest levels:")
display(summary)
# Out:
# Negative words found: ['worry', 'suffering']
# Pandemic words found: []
# Average interest levels:
#                pre_covid     covid  post_covid
# negative_mean   3.104167  3.227273    4.761905
# pandemic_mean        NaN       NaN         NaN

# %% [markdown]
# Token counts for the word groups from above but for our dataset across years.

# %%
CSV_PATH = "data/newyorker_caption_contest/df_complete.csv"
DATE_COL = "date"
TEXT_COLS = [
    "image_locations",
    "image_descriptions",
    "image_uncanny_descriptions",
    "questions",
]

# Your word groups. Each tuple is a dict key.
word_groups = [
    ("fear", "death", "anxiety", "sad", "worry", "crisis", "anger", "pain", "stress", "hate", "war", "depression", "trauma", "suffering", "loss", "grief", "panic", "nervous", "frustration", "helplessness"),
    ("pandemic", "virus", "covid", "quarantine", "lockdown", "vaccine", "mask", "social", "isolation", "outbreak", "immunity", "testing", "symptoms", "healthcare", "hygiene", "sanitizer", "ventilator","immunity", "distance"),
]

USE_LEMMA = True
try:
    from nltk.stem import WordNetLemmatizer
    import nltk
    nltk.download("wordnet", quiet=True)
    nltk.download("omw-1.4", quiet=True)
    LEMMA = WordNetLemmatizer()
except Exception:
    USE_LEMMA = False
    LEMMA = None


_word_re = re.compile(r"[a-z]+")  # only a-z tokens

def normalize_token(t: str) -> str:
    t = t.lower()
    if USE_LEMMA and LEMMA:
        t = LEMMA.lemmatize(t)
    return t

def tokenize_text(text) -> list[str]:
    if not isinstance(text, str) or not text:
        return []
    return [normalize_token(m.group(0)) for m in _word_re.finditer(text.lower())]

# wonthly frequencies per group
def build_group_month_frequencies(df: pd.DataFrame,
                                  text_cols=TEXT_COLS,
                                  groups=word_groups,
                                  date_col=DATE_COL) -> dict[tuple, dict[str, int]]:
    """
    Returns: {('w1','w2',...): {'YYYY-MM': count, ...}, ...}
    """
    # ensure columns exist
    missing = [c for c in text_cols + [date_col] if c not in df.columns]
    if missing:
        raise ValueError(f"Missing columns in df: {missing}")

    # month as pandas Period 'M'
    months = pd.to_datetime(df[date_col], errors="coerce").dt.to_period("M")

    # map token -> groups containing it
    token_to_groups = defaultdict(set)
    for grp in groups:
        for w in grp:
            token_to_groups[normalize_token(w)].add(grp)

    # counts
    result: dict[tuple, defaultdict[str, int]] = {
        grp: defaultdict(int) for grp in groups
    }

    for i, row in df.iterrows():
        m = months.iat[i]
        if pd.isna(m):
            continue
        m_key = str(m)  # 'YYYY-MM'

        tokens: list[str] = []
        for col in text_cols:
            tokens.extend(tokenize_text(row[col]))
        counts = Counter(tokens)

        for tok, c in counts.items():
            if tok in token_to_groups and c > 0:
                for grp in token_to_groups[tok]:
                    result[grp][m_key] += c

    # sort inner dicts by month
    def sort_month_dict(d: dict[str, int]) -> dict[str, int]:
        # convert keys back to Period for sorting
        items = sorted(d.items(), key=lambda kv: pd.Period(kv[0], freq="M"))
        return dict(items)

    final = {grp: sort_month_dict(months_dict) for grp, months_dict in result.items()}
    return final


if __name__ == "__main__":
    # 1) Load CSV
    if not os.path.exists(CSV_PATH):
        raise FileNotFoundError(f"CSV not found: {CSV_PATH}")
    df_complete = pd.read_csv(CSV_PATH)

    # 2) Build nested dict (monthly)
    group_month_freq = build_group_month_frequencies(df_complete)

    for grp, md in group_month_freq.items():
        print(f"{grp}: {list(md.items())[:6]} ...")  # first few months

    # 3) Plot (monthly timeline)
    # Collect all months appearing in any group
    all_month_strs = sorted(
        {m for d in group_month_freq.values() for m in d.keys()},
        key=lambda s: pd.Period(s, freq="M"),
    )
    if not all_month_strs:
        print("No dated tokens found for the given groups.")
    else:
        # convert to timestamps for plotting
        x_periods = [pd.Period(s, freq="M") for s in all_month_strs]
        x_dates = [p.to_timestamp() for p in x_periods]

        plt.figure(figsize=(9, 5))
        for grp, mdict in group_month_freq.items():
            y_vals = [mdict.get(s, 0) for s in all_month_strs]
            plt.plot(x_dates, y_vals, marker="o", label=", ".join(grp))

        plt.xlabel("Month")
        plt.ylabel("Frequency (token count)")
        plt.title("Grouped word frequencies per month")
        plt.xticks(rotation=45)
        plt.tight_layout()
        plt.legend()
        plt.show()
# Out:
# ('fear', 'death', 'anxiety', 'sad', 'worry', 'crisis', 'anger', 'pain', 'stress', 'hate', 'war', 'depression', 'trauma', 'suffering', 'loss', 'grief', 'panic', 'nervous', 'frustration', 'helplessness'): [('2016-04', 2), ('2016-05', 1), ('2016-10', 4), ('2017-01', 1), ('2017-03', 3), ('2017-12', 3)] ...
# ('pandemic', 'virus', 'covid', 'quarantine', 'lockdown', 'vaccine', 'mask', 'social', 'isolation', 'outbreak', 'immunity', 'testing', 'symptoms', 'healthcare', 'hygiene', 'sanitizer', 'ventilator', 'immunity', 'distance'): [('2016-07', 1), ('2017-03', 1), ('2019-01', 1), ('2020-11', 1)] ...

# %% [markdown]
# ### Humor types clustering

# %%
# humor_types_clustering

FILES = [
    "data/GoogleTrends/frequent_words/image_descriptions__unigrams_nltk.csv",
    "data/GoogleTrends/frequent_words/image_locations__unigrams_nltk.csv",
    "data/GoogleTrends/frequent_words/image_uncanny_descriptions__unigrams_nltk.csv",
    "data/GoogleTrends/frequent_words/questions__unigrams_nltk.csv",
]
dfs = [pd.read_csv(f) for f in FILES]
df = pd.concat(dfs, ignore_index=True)

df["token"] = df["token"].astype(str).str.lower().str.strip()
df = (df.groupby("token", as_index=False)["count"]
        .sum()
        .sort_values("count", ascending=False))
#filter 
df = df[df["token"].str.len() >= 3]


HUMOR_TYPES = {
    "dark_humor": [
        "death","dying","killer","grave","cemetery","coffin","suicide","grim","morbidity",
        "funeral","mourning","doom","bleak","apocalypse","disease","cancer","war","bomb"
    ],
    "wordplay_puns": [
        "pun","wordplay","double meaning","homophone","homonym","punny","dad joke","literal",
        "misunderstanding","twist","ambiguity","rhyme","alliteration"
    ],
    "sarcasm_irony": [
        "sarcasm","sarcastic","irony","ironic","deadpan","mock","snark","understatement",
        "overstatement","hyperbole","satire","sardonic"
    ],
    "absurd_surreal": [
        "absurd","surreal","nonsense","impossible","paradox","bizarre","weird","alien",
        "unicorn","centaur","talking animal","ufo","dreamlike","nonsensical"
    ],
    "topical_political": [
        "election","vote","president","campaign","trump","biden","senate","congress","policy",
        "covid","pandemic","mask","lockdown","vaccine","war","protest","economy","inflation"
    ],
    "relationship_family": [
        "marriage","wife","husband","boyfriend","girlfriend","date","relationship","family",
        "kids","parents","mother","father","valentine","romance","breakup","divorce"
    ],
    "workplace_office": [
        "office","meeting","boss","coworker","email","deadline","promotion","salary","zoom",
        "spreadsheet","presentation","desk","manager","client"
    ],
    "animals": [
        "dog","cat","bird","fish","horse","cow","duck","bear","monkey","elephant","zebra",
        "lion","tiger","pet","leash","vet","fur","bark","meow"
    ],
}


model = SentenceTransformer("all-MiniLM-L6-v2")

TOKEN_LIST = df["token"].tolist()
E_tokens = model.encode(TOKEN_LIST, batch_size=256, show_progress_bar=True)

type_names = list(HUMOR_TYPES.keys())
seed_texts = [" ".join(HUMOR_TYPES[t]) for t in type_names]  
E_types = model.encode(seed_texts, show_progress_bar=False)

S = cosine_similarity(E_tokens, E_types)

freq = df["count"].to_numpy()
freq_norm = (freq - freq.min()) / (freq.max() - freq.min() + 1e-9)

best_idx = S.argmax(axis=1)
df["humor_type"] = [type_names[i] for i in best_idx]
df["type_score"] = S.max(axis=1)

for i, t in enumerate(type_names):
    df[f"score_{t}"] = S[:, i]

MIN_SCORE = 0.40 
df_high = df[df["type_score"] >= MIN_SCORE].copy()


# Save labeled vocabulary for later use

out_dir = Path("data/humor_types")
out_dir.mkdir(parents=True, exist_ok=True)
df.to_csv(out_dir / "tokens_labeled_all.csv", index=False)
df_high.to_csv(out_dir / "tokens_labeled_confident.csv", index=False)

# Quick inspection: top words per humor type
def show_top_words(df_labelled, k=15):
    for t in type_names:
        sub = (df_labelled[df_labelled["humor_type"] == t]
               .sort_values(["type_score","count"], ascending=False)
               .head(k))
        print(f"\n=== {t} ===")
        print(", ".join(sub["token"].tolist()))

show_top_words(df_high, k=15)


try:
    X2 = PCA(n_components=2, random_state=42).fit_transform(E_tokens)
    df_vis = df.copy()
    df_vis["x"] = X2[:,0]
    df_vis["y"] = X2[:,1]

    plt.figure(figsize=(11,9))
    for t in type_names:
        m = df_vis["humor_type"] == t
        plt.scatter(
            df_vis.loc[m,"x"], df_vis.loc[m,"y"],
            s=10 + 90*freq_norm[m], alpha=0.6, label=t
        )
    plt.title("Humor-type map (tokens colored by assigned humor type)")
    plt.legend(bbox_to_anchor=(1.05, 1), loc="upper left")
    plt.tight_layout()
    plt.savefig(out_dir / "humor_types_map.png", dpi=200)
    plt.show()
except Exception as e:
    print("Plot skipped:", e)

for t in type_names:
    sub = df_high[df_high["humor_type"] == t][["token","count","type_score"]]
    sub.to_csv(out_dir / f"lexicon_{t}.csv", index=False)

print("\nDone. Saved:")
print("- data/humor_types/tokens_labeled_all.csv")
print("- data/humor_types/tokens_labeled_confident.csv")
print("- data/humor_types/lexicon_<type>.csv (per humor type)")
print("- data/humor_types/humor_types_map.png (if PCA succeeded)")
# Out:
# Batches:   0%|          | 0/9 [00:00<?, ?it/s]
# === dark_humor ===
# graveyard, funeral, cemetery, coffin, corpses, coffins, death, killing, reaper, die
#
# === wordplay_puns ===
#
#
# === sarcasm_irony ===
#
#
# === absurd_surreal ===
# ufo, centaur, centaurs, ufos, mythical, aliens, unicorn, unicorns, alien
#
# === topical_political ===
#
#
# === relationship_family ===
# couple, marrying
#
# === workplace_office ===
#
#
# === animals ===
# pets, animals, animal, cats, dogs, cat, barking, leash, lion, collar, dog, collars, bird, dolphin, horse
# Done. Saved:
# - data/humor_types/tokens_labeled_all.csv
# - data/humor_types/tokens_labeled_confident.csv
# - data/humor_types/lexicon_<type>.csv (per humor type)
# - data/humor_types/humor_types_map.png (if PCA succeeded)

# %%
dfc = df_complete.copy()

# unify date column
date_col = "Date" if "Date" in dfc.columns else ("date" if "date" in dfc.columns else None)
if date_col is None:
    raise ValueError("No Date/date column found in df_complete.")
dfc["Date"] = pd.to_datetime(dfc[date_col], errors="coerce")

text_cols_str = [c for c in ["Top Rated caption", "The New Yorker's winner"] if c in dfc.columns]
text_cols_list = [c for c in ["image_descriptions","image_uncanny_descriptions","image_locations","entities","questions"]
                  if c in dfc.columns]

def to_text(x):
    """Convert cell to a space-joined string."""
    if isinstance(x, (list, tuple)):
        return " ".join(str(t) for t in x if pd.notna(t))
    if pd.isna(x):
        return ""
    return str(x)

doc_parts = []
for col in text_cols_str + text_cols_list:
    doc_parts.append(dfc[col].apply(to_text) if col in dfc.columns else "")

# concatenated document per contest
dfc["doc"] = pd.Series([""] * len(dfc))
for part in doc_parts:
    dfc["doc"] = (dfc["doc"].astype(str) + " " + part.astype(str)).str.strip()

# Clean minimal (lowercase, keep letters/apostrophes/spaces)
dfc["doc"] = (dfc["doc"].str.lower()
                        .str.replace(r"[^a-z'\s]", " ", regex=True)
                        .str.replace(r"\s+", " ", regex=True)
                        .str.strip())


lex_path = Path("data/humor_types/tokens_labeled_confident.csv")
lex = pd.read_csv(lex_path)

# tighten lexicon (tune thresholds if needed)
if "type_score" in lex and "count" in lex:
    lex = lex[(lex["type_score"] >= 0.45) & (lex["count"] >= 5)].copy()

lex["token"] = lex["token"].astype(str).str.lower().str.strip()
type2tokens = (lex.groupby("humor_type")["token"]
                 .apply(lambda s: set(s.tolist()))
                 .to_dict())
humor_types = list(type2tokens.keys())
print("Humor types:", humor_types)

#  Tag contests: which humor types appear in each contest document?
token_re = re.compile(r"[a-z']+")

def doc_types(text: str):
    words = set(token_re.findall(text))
    hits = [t for t, toks in type2tokens.items() if len(words & toks) > 0]
    return hits

dfc["humor_types"] = dfc["doc"].apply(doc_types)

#  store a boolean indicator per type 
for t in humor_types:
    dfc[f"type__{t}"] = dfc["humor_types"].apply(lambda L: t in L)


#  Weekly time series (per-humor-type counts & proportions of contests)
dfc = dfc.dropna(subset=["Date"])
dfc["week"] = dfc["Date"].dt.to_period("W").apply(lambda p: p.start_time)

# explode to (contest, type) rows for counting
df_expl = dfc.explode("humor_types")
df_expl["humor_types"] = df_expl["humor_types"].fillna("unlabeled")

# per week per type: number of contests that include that type
week_counts = (df_expl.groupby(["week","humor_types"])
                        .size()
                        .rename("contests_with_type")
                        .reset_index())

# total contests per week (denominator for proportions)
week_totals = (dfc.groupby("week")["contest_id"]
                 .nunique()
                 .rename("total_contests")
                 .reset_index())

weekly = week_counts.merge(week_totals, on="week", how="left")
weekly["prop_contests"] = weekly["contests_with_type"] / weekly["total_contests"].replace(0, np.nan)

# Save tidy weekly table
out_dir = Path("data/humor_types")
out_dir.mkdir(parents=True, exist_ok=True)
weekly.to_csv(out_dir / "weekly_humor_types_contest_level.csv", index=False)


weekly_labeled = weekly[weekly["humor_types"]!="unlabeled"].copy()
top_types = (weekly_labeled.groupby("humor_types")["contests_with_type"]
                          .sum()
                          .sort_values(ascending=False)
                          .head(6).index.tolist())

plt.figure(figsize=(11,6))
linestyles = ['-', '--', ':', '-.']
for i, t in enumerate(top_types):
    sub = weekly_labeled[weekly_labeled["humor_types"] == t].sort_values("week")
    plt.plot(sub["week"], sub["prop_contests"], label=t,
             linewidth=2, alpha=0.8, linestyle=linestyles[i % len(linestyles)])

plt.title("Humor types over time (share of contests per week)")
plt.xlabel("Week")
plt.ylabel("Proportion of contests with that humor type")
plt.legend()
plt.tight_layout()
plt.show()

print("Saved:", out_dir / "weekly_humor_types_contest_level.csv")
# Out:
# Humor types: ['absurd_surreal', 'animals', 'dark_humor']
# Saved: data/humor_types/weekly_humor_types_contest_level.csv
